# %% [markdown]
# # ETL Project: US Health Department Fundings

# %%
# Import Dependencies
import pandas as pd
from sqlalchemy import create_engine
import requests
import json
from pprint import pprint

# %% [markdown]
# ## US Aggregate

# %%
# Import US Aggregate CSV File
csv_file = "Resources/US_AGGREGATE14.csv"
nhe_df = pd.read_csv(csv_file)
nhe_df.head()
# Out:
#    Code                                        Item          Group  \
# 0     1  Personal Health Care (Millions of Dollars)  United States
# 1     1  Personal Health Care (Millions of Dollars)         Region
# 2     1  Personal Health Care (Millions of Dollars)         Region
# 3     1  Personal Health Care (Millions of Dollars)         Region
# 4     1  Personal Health Care (Millions of Dollars)         Region
#
#    Region_Number    Region_Name State_Name   Y1991   Y1992   Y1993   Y1994  \
# 0              0  United States        NaN  675896  731455  778684  820172
# 1              1    New England        NaN   41141   43852   46559   48652
# 2              2        Mideast        NaN  135649  146771  156070  164568
# 3              3    Great Lakes        NaN  112928  121704  129472  136223
# 4              4         Plains        NaN   45974   49328   52338   56106
#
#    ...    Y2006    Y2007    Y2008    Y2009    Y2010    Y2011    Y2012  \
# 0  ...  1804672  1918820  2010690  2114221  2194625  2272582  2365948
# 1  ...   108337   115472   121374   128237   131705   135127   139653
# 2  ...   336138   354513   367687   386829   401722   415463   425105
# 3  ...   283469   299660   310106   326869   339536   350011   364863
# 4  ...   123934   132554   139251   145313   151164   157465   163907
#
#      Y2013    Y2014  Average_Annual_Percent_Growth
# 0  2435624  2562824                            6.0
# 1   143519   148571                            5.7
# 2   437986   459082                            5.4
# 3   373505   392044                            5.6
# 4   168202   175912                            6.0
#
# [5 rows x 31 columns]

# %%
# Filter to only get United States data
filtered_us_df = nhe_df.loc[nhe_df["Region_Name"] == "United States"]
filtered_us_df.head()
# Out:
#      Code                                               Item          Group  \
# 0       1         Personal Health Care (Millions of Dollars)  United States
# 60      2                Hospital Care (Millions of Dollars)  United States
# 120     3  Physician & Clinical Services (Millions of Dol...  United States
# 180     4  Other Professional Services (Millions of Dollars)  United States
# 240     5              Dental Services (Millions of Dollars)  United States
#
#      Region_Number    Region_Name State_Name   Y1991   Y1992   Y1993   Y1994  \
# 0                0  United States        NaN  675896  731455  778684  820172
# 60               0  United States        NaN  275768  298477  315749  328366
# 120              0  United States        NaN  175750  190156  201417  210479
# 180              0  United States        NaN   18559   20860   22956   23974
# 240              0  United States        NaN   33397   37133   39006   41558
#
#      ...    Y2006    Y2007    Y2008    Y2009    Y2010    Y2011    Y2012  \
# 0    ...  1804672  1918820  2010690  2114221  2194625  2272582  2365948
# 60   ...   651220   691973   725711   779689   822405   852020   902676
# 120  ...   435759   458562   482925   498724   513144   536395   558024
# 180  ...    55264    60055    64540    67152    69849    72748    76429
# 240  ...    91146    97029   101939   102307   105032   107106   108771
#
#        Y2013    Y2014  Average_Annual_Percent_Growth
# 0    2435624  2562824                            6.0
# 60    937877   980966                            5.7
# 120   569542   597137                            5.5
# 180    78796    82826                            6.7
# 240   110141   112832                            5.4
#
# [5 rows x 31 columns]

# %%
# Get the column names
filtered_us_df.columns
# Out:
# Index(['Code', 'Item', 'Group', 'Region_Number', 'Region_Name', 'State_Name',
#        'Y1991', 'Y1992', 'Y1993', 'Y1994', 'Y1995', 'Y1996', 'Y1997', 'Y1998',
#        'Y1999', 'Y2000', 'Y2001', 'Y2002', 'Y2003', 'Y2004', 'Y2005', 'Y2006',
#        'Y2007', 'Y2008', 'Y2009', 'Y2010', 'Y2011', 'Y2012', 'Y2013', 'Y2014',
#        'Average_Annual_Percent_Growth'],
#       dtype='object')

# %%
# Transforming the DataFrame
# Reset the index
reset_us_df = filtered_us_df.reset_index()

# Store only the necessary columns
new_us_df = reset_us_df[['Item', 'Y1991', 'Y1992', 'Y1993', 'Y1994', 'Y1995', 'Y1996', 'Y1997', 'Y1998',
       'Y1999', 'Y2000', 'Y2001', 'Y2002', 'Y2003', 'Y2004', 'Y2005', 'Y2006',
       'Y2007', 'Y2008', 'Y2009', 'Y2010', 'Y2011', 'Y2012', 'Y2013', 'Y2014']].copy()

# Rename for easier usage
transformed_us_df = new_us_df.rename(columns={
    'Item':'item',
    'Y1991':'1991',
    'Y1992':'1992',
    'Y1993':'1993',
    'Y1994':'1994',
    'Y1995':'1995',
    'Y1996':'1996',
    'Y1997':'1997',
    'Y1998':'1998',
    'Y1999':'1999',
    'Y2000':'2000',
    'Y2001':'2001',
    'Y2002':'2002',
    'Y2003':'2003',
    'Y2004':'2004',
    'Y2005':'2005',
    'Y2006':'2006',
    'Y2007':'2007',
    'Y2008':'2008',
    'Y2009':'2009',
    'Y2010':'2010',
    'Y2011':'2011',
    'Y2012':'2012',
    'Y2013':'2013',
    'Y2014':'2014'
})
transformed_us_df.head()
# Out:
#                                                 item    1991    1992    1993  \
# 0         Personal Health Care (Millions of Dollars)  675896  731455  778684
# 1                Hospital Care (Millions of Dollars)  275768  298477  315749
# 2  Physician & Clinical Services (Millions of Dol...  175750  190156  201417
# 3  Other Professional Services (Millions of Dollars)   18559   20860   22956
# 4              Dental Services (Millions of Dollars)   33397   37133   39006
#
#      1994    1995    1996    1997     1998     1999  ...     2005     2006  \
# 0  820172  869578  917540  969531  1026103  1086280  ...  1696222  1804672
# 1  328366  339313  350799  363404   374917   393624  ...   608553   651220
# 2  210479  220303  228423  239143   256929   270034  ...   414050   435759
# 3   23974   26671   28857   31275    33424    34614  ...    52795    55264
# 4   41558   44615   46943   50292    53600    57255  ...    86691    91146
#
#       2007     2008     2009     2010     2011     2012     2013     2014
# 0  1918820  2010690  2114221  2194625  2272582  2365948  2435624  2562824
# 1   691973   725711   779689   822405   852020   902676   937877   980966
# 2   458562   482925   498724   513144   536395   558024   569542   597137
# 3    60055    64540    67152    69849    72748    76429    78796    82826
# 4    97029   101939   102307   105032   107106   108771   110141   112832
#
# [5 rows x 25 columns]

# %% [markdown]
# ## Ebola

# %%
# Ebola CSV file
ebola_csv = "Resources/ebola_data_db_format.csv"
ebola_df = pd.read_csv(ebola_csv)
ebola_df.head()
# Out:
#                                            Indicator Country        Date  \
# 0  Cumulative number of confirmed, probable and s...  Guinea  2015-03-10
# 1         Cumulative number of confirmed Ebola cases  Guinea  2015-03-10
# 2          Cumulative number of probable Ebola cases  Guinea  2015-03-10
# 3         Cumulative number of suspected Ebola cases  Guinea  2015-03-10
# 4  Cumulative number of confirmed, probable and s...  Guinea  2015-03-10
#
#     value
# 0  3285.0
# 1  2871.0
# 2   392.0
# 3    22.0
# 4  2170.0

# %%
# Transforming the DataFrame
# Filter by Country by USA
us_ebola_df = ebola_df.loc[ebola_df["Country"] == "United States of America"]

# Filter by Total
cleaned_ebola_df = us_ebola_df.loc[us_ebola_df['Indicator'] == "Cumulative number of confirmed, probable and suspected Ebola cases"]

# Reset the index
reset_df = cleaned_ebola_df.reset_index()

# Have only necessary columns
finished_ebola_df = reset_df[["Indicator", "Date", "value"]]
finished_ebola_df

# Rename for easier use
transformed_ebola_df = finished_ebola_df.rename(columns={
    "Indicator":"indicator",
    "Date":"date"
})
transformed_ebola_df
# Out:
#                                              indicator        date  value
# 0    Cumulative number of confirmed, probable and s...  2015-03-10    4.0
# 1    Cumulative number of confirmed, probable and s...  2015-03-06    4.0
# 2    Cumulative number of confirmed, probable and s...  2015-03-05    4.0
# 3    Cumulative number of confirmed, probable and s...  2015-03-04    4.0
# 4    Cumulative number of confirmed, probable and s...  2015-03-02    4.0
# ..                                                 ...         ...    ...
# 240  Cumulative number of confirmed, probable and s...  2015-12-17    4.0
# 241  Cumulative number of confirmed, probable and s...  2015-12-22    4.0
# 242  Cumulative number of confirmed, probable and s...  2015-12-23    4.0
# 243  Cumulative number of confirmed, probable and s...  2015-12-29    4.0
# 244  Cumulative number of confirmed, probable and s...  2016-03-23    4.0
#
# [245 rows x 3 columns]

# %% [markdown]
# ## HIV/AIDS

# %%
# Import HIV/AIDS JSON file
#json_file = "Resources/datapackage.json"
#hiv_df = pd.read_json(json_file)

# %%
# Import HIV/AIDS CSV file
hiv_csv = "Resources/hiv-aids-cases-2.csv"
hiv_df = pd.read_csv(hiv_csv)
hiv_df.head()
# Out:
#    Year          Category  Group  Count
# 0  2011  Age at Diagnosis   0-11     16
# 1  2011  Age at Diagnosis  12-14      2
# 2  2011  Age at Diagnosis  15-17     25
# 3  2011  Age at Diagnosis  18-19    137
# 4  2011  Age at Diagnosis  20-24    725

# %%
# Transforming the DataFrame
transformed_hiv_df = hiv_df[["Year", "Count"]]
transformed_hiv_df.head()
# Out:
#    Year  Count
# 0  2011     16
# 1  2011      2
# 2  2011     25
# 3  2011    137
# 4  2011    725

# %% [markdown]
# ## COVID-19 Cases

# %%
# Query data from COVID-19 API
url = 'https://api.covid19api.com/summary'
data_json = requests.get(url).json()
pprint(data_json)
# Out:
# {'Countries': [{'Country': 'Afghanistan',
#                 'CountryCode': 'AF',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 591,
#                 'NewDeaths': 1,
#                 'NewRecovered': 22,
#                 'Slug': 'afghanistan',
#                 'TotalConfirmed': 11173,
#                 'TotalDeaths': 219,
#                 'TotalRecovered': 1097},
#                {'Country': 'Albania',
#                 'CountryCode': 'AL',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 6,
#                 'NewDeaths': 0,
#                 'NewRecovered': 6,
#                 'Slug': 'albania',
#                 'TotalConfirmed': 1004,
#                 'TotalDeaths': 32,
#                 'TotalRecovered': 795},
#                {'Country': 'Algeria',
#                 'CountryCode': 'DZ',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 197,
#                 'NewDeaths': 9,
#                 'NewRecovered': 0,
#                 'Slug': 'algeria',
#                 'TotalConfirmed': 8503,
#                 'TotalDeaths': 609,
#                 'TotalRecovered': 4784},
#                {'Country': 'Andorra',
#                 'CountryCode': 'AD',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 1,
#                 'NewDeaths': 0,
#                 'NewRecovered': 10,
#                 'Slug': 'andorra',
#                 'TotalConfirmed': 763,
#                 'TotalDeaths': 51,
#                 'TotalRecovered': 663},
#                {'Country': 'Angola',
#                 'CountryCode': 'AO',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 1,
#                 'NewDeaths': 0,
#                 'NewRecovered': 0,
#                 'Slug': 'angola',
#                 'TotalConfirmed': 70,
#                 'TotalDeaths': 4,
#                 'TotalRecovered': 18},
#                {'Country': 'Antigua and Barbuda',
#                 'CountryCode': 'AG',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 0,
#                 'NewDeaths': 0,
#                 'NewRecovered': 0,
#                 'Slug': 'antigua-and-barbuda',
#                 'TotalConfirmed': 25,
#                 'TotalDeaths': 3,
#                 'TotalRecovered': 19},
#                {'Country': 'Argentina',
#                 'CountryCode': 'AR',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 552,
#                 'NewDeaths': 15,
#                 'NewRecovered': 267,
#                 'Slug': 'argentina',
#                 'TotalConfirmed': 12628,
#                 'TotalDeaths': 467,
#                 'TotalRecovered': 3999},
#                {'Country': 'Armenia',
#                 'CountryCode': 'AM',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 452,
#                 'NewDeaths': 6,
#                 'NewRecovered': 81,
#                 'Slug': 'armenia',
#                 'TotalConfirmed': 7113,
#                 'TotalDeaths': 87,
#                 'TotalRecovered': 3145},
#                {'Country': 'Australia',
#                 'CountryCode': 'AU',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 12,
#                 'NewDeaths': 0,
#                 'NewRecovered': 21,
#                 'Slug': 'australia',
#                 'TotalConfirmed': 7126,
#                 'TotalDeaths': 102,
#                 'TotalRecovered': 6552},
#                {'Country': 'Austria',
#                 'CountryCode': 'AT',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 36,
#                 'NewDeaths': 1,
#                 'NewRecovered': 75,
#                 'Slug': 'austria',
#                 'TotalConfirmed': 16539,
#                 'TotalDeaths': 641,
#                 'TotalRecovered': 15138},
#                {'Country': 'Azerbaijan',
#                 'CountryCode': 'AZ',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 149,
#                 'NewDeaths': 2,
#                 'NewRecovered': 134,
#                 'Slug': 'azerbaijan',
#                 'TotalConfirmed': 4271,
#                 'TotalDeaths': 51,
#                 'TotalRecovered': 2741},
#                {'Country': 'Bahamas',
#                 'CountryCode': 'BS',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 0,
#                 'NewDeaths': 0,
#                 'NewRecovered': 1,
#                 'Slug': 'bahamas',
#                 'TotalConfirmed': 100,
#                 'TotalDeaths': 11,
#                 'TotalRecovered': 46},
#                {'Country': 'Bahrain',
#                 'CountryCode': 'BH',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 33,
#                 'NewDeaths': 0,
#                 'NewRecovered': 166,
#                 'Slug': 'bahrain',
#                 'TotalConfirmed': 9171,
#                 'TotalDeaths': 14,
#                 'TotalRecovered': 4753},
#                {'Country': 'Bangladesh',
#                 'CountryCode': 'BD',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 1975,
#                 'NewDeaths': 21,
#                 'NewRecovered': 433,
#                 'Slug': 'bangladesh',
#                 'TotalConfirmed': 35585,
#                 'TotalDeaths': 501,
#                 'TotalRecovered': 7334},
#                {'Country': 'Barbados',
#                 'CountryCode': 'BB',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 0,
#                 'NewDeaths': 0,
#                 'NewRecovered': 1,
#                 'Slug': 'barbados',
#                 'TotalConfirmed': 92,
#                 'TotalDeaths': 7,
#                 'TotalRecovered': 71},
#                {'Country': 'Belarus',
#                 'CountryCode': 'BY',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 946,
#                 'NewDeaths': 5,
#                 'NewRecovered': 294,
#                 'Slug': 'belarus',
#                 'TotalConfirmed': 37144,
#                 'TotalDeaths': 204,
#                 'TotalRecovered': 14449},
#                {'Country': 'Belgium',
#                 'CountryCode': 'BE',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 250,
#                 'NewDeaths': 32,
#                 'NewRecovered': 25,
#                 'Slug': 'belgium',
#                 'TotalConfirmed': 57342,
#                 'TotalDeaths': 9312,
#                 'TotalRecovered': 15297},
#                {'Country': 'Belize',
#                 'CountryCode': 'BZ',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 0,
#                 'NewDeaths': 0,
#                 'NewRecovered': 0,
#                 'Slug': 'belize',
#                 'TotalConfirmed': 18,
#                 'TotalDeaths': 2,
#                 'TotalRecovered': 16},
#                {'Country': 'Benin',
#                 'CountryCode': 'BJ',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 0,
#                 'NewDeaths': 0,
#                 'NewRecovered': 2,
#                 'Slug': 'benin',
#                 'TotalConfirmed': 191,
#                 'TotalDeaths': 3,
#                 'TotalRecovered': 84},
#                {'Country': 'Bhutan',
#                 'CountryCode': 'BT',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 3,
#                 'NewDeaths': 0,
#                 'NewRecovered': 0,
#                 'Slug': 'bhutan',
#                 'TotalConfirmed': 27,
#                 'TotalDeaths': 0,
#                 'TotalRecovered': 6},
#                {'Country': 'Bolivia',
#                 'CountryCode': 'BO',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 397,
#                 'NewDeaths': 11,
#                 'NewRecovered': 18,
#                 'Slug': 'bolivia',
#                 'TotalConfirmed': 6660,
#                 'TotalDeaths': 261,
#                 'TotalRecovered': 647},
#                {'Country': 'Bosnia and Herzegovina',
#                 'CountryCode': 'BA',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 5,
#                 'NewDeaths': 2,
#                 'NewRecovered': 16,
#                 'Slug': 'bosnia-and-herzegovina',
#                 'TotalConfirmed': 2406,
#                 'TotalDeaths': 146,
#                 'TotalRecovered': 1696},
#                {'Country': 'Botswana',
#                 'CountryCode': 'BW',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 0,
#                 'NewDeaths': 0,
#                 'NewRecovered': 0,
#                 'Slug': 'botswana',
#                 'TotalConfirmed': 35,
#                 'TotalDeaths': 1,
#                 'TotalRecovered': 19},
#                {'Country': 'Brazil',
#                 'CountryCode': 'BR',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 11687,
#                 'NewDeaths': 807,
#                 'NewRecovered': 3922,
#                 'Slug': 'brazil',
#                 'TotalConfirmed': 374898,
#                 'TotalDeaths': 23473,
#                 'TotalRecovered': 153833},
#                {'Country': 'Brunei Darussalam',
#                 'CountryCode': 'BN',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 0,
#                 'NewDeaths': 0,
#                 'NewRecovered': 0,
#                 'Slug': 'brunei',
#                 'TotalConfirmed': 141,
#                 'TotalDeaths': 1,
#                 'TotalRecovered': 137},
#                {'Country': 'Bulgaria',
#                 'CountryCode': 'BG',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 6,
#                 'NewDeaths': 0,
#                 'NewRecovered': 22,
#                 'Slug': 'bulgaria',
#                 'TotalConfirmed': 2433,
#                 'TotalDeaths': 130,
#                 'TotalRecovered': 862},
#                {'Country': 'Burkina Faso',
#                 'CountryCode': 'BF',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 18,
#                 'NewDeaths': 0,
#                 'NewRecovered': 0,
#                 'Slug': 'burkina-faso',
#                 'TotalConfirmed': 832,
#                 'TotalDeaths': 52,
#                 'TotalRecovered': 672},
#                {'Country': 'Burundi',
#                 'CountryCode': 'BI',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 0,
#                 'NewDeaths': 0,
#                 'NewRecovered': 0,
#                 'Slug': 'burundi',
#                 'TotalConfirmed': 42,
#                 'TotalDeaths': 1,
#                 'TotalRecovered': 20},
#                {'Country': 'Cambodia',
#                 'CountryCode': 'KH',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 0,
#                 'NewDeaths': 0,
#                 'NewRecovered': 0,
#                 'Slug': 'cambodia',
#                 'TotalConfirmed': 124,
#                 'TotalDeaths': 0,
#                 'TotalRecovered': 122},
#                {'Country': 'Cameroon',
#                 'CountryCode': 'CM',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 0,
#                 'NewDeaths': 0,
#                 'NewRecovered': 0,
#                 'Slug': 'cameroon',
#                 'TotalConfirmed': 4890,
#                 'TotalDeaths': 165,
#                 'TotalRecovered': 1865},
#                {'Country': 'Canada',
#                 'CountryCode': 'CA',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 2026,
#                 'NewDeaths': 242,
#                 'NewRecovered': 653,
#                 'Slug': 'canada',
#                 'TotalConfirmed': 174236,
#                 'TotalDeaths': 13308,
#                 'TotalRecovered': 44651},
#                {'Country': 'Cape Verde',
#                 'CountryCode': 'CV',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 10,
#                 'NewDeaths': 0,
#                 'NewRecovered': 0,
#                 'Slug': 'cape-verde',
#                 'TotalConfirmed': 390,
#                 'TotalDeaths': 3,
#                 'TotalRecovered': 155},
#                {'Country': 'Central African Republic',
#                 'CountryCode': 'CF',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 48,
#                 'NewDeaths': 0,
#                 'NewRecovered': 0,
#                 'Slug': 'central-african-republic',
#                 'TotalConfirmed': 652,
#                 'TotalDeaths': 1,
#                 'TotalRecovered': 22},
#                {'Country': 'Chad',
#                 'CountryCode': 'TD',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 12,
#                 'NewDeaths': 1,
#                 'NewRecovered': 29,
#                 'Slug': 'chad',
#                 'TotalConfirmed': 687,
#                 'TotalDeaths': 61,
#                 'TotalRecovered': 244},
#                {'Country': 'Chile',
#                 'CountryCode': 'CL',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 4895,
#                 'NewDeaths': 43,
#                 'NewRecovered': 1154,
#                 'Slug': 'chile',
#                 'TotalConfirmed': 73997,
#                 'TotalDeaths': 761,
#                 'TotalRecovered': 29302},
#                {'Country': 'China',
#                 'CountryCode': 'CN',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 7,
#                 'NewDeaths': 0,
#                 'NewRecovered': 9,
#                 'Slug': 'china',
#                 'TotalConfirmed': 84102,
#                 'TotalDeaths': 4638,
#                 'TotalRecovered': 79352},
#                {'Country': 'Colombia',
#                 'CountryCode': 'CO',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 806,
#                 'NewDeaths': 23,
#                 'NewRecovered': 249,
#                 'Slug': 'colombia',
#                 'TotalConfirmed': 21981,
#                 'TotalDeaths': 750,
#                 'TotalRecovered': 5265},
#                {'Country': 'Comoros',
#                 'CountryCode': 'KM',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 0,
#                 'NewDeaths': 0,
#                 'NewRecovered': 0,
#                 'Slug': 'comoros',
#                 'TotalConfirmed': 87,
#                 'TotalDeaths': 1,
#                 'TotalRecovered': 21},
#                {'Country': 'Congo (Brazzaville)',
#                 'CountryCode': 'CG',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 0,
#                 'NewDeaths': 0,
#                 'NewRecovered': 0,
#                 'Slug': 'congo-brazzaville',
#                 'TotalConfirmed': 487,
#                 'TotalDeaths': 16,
#                 'TotalRecovered': 147},
#                {'Country': 'Congo (Kinshasa)',
#                 'CountryCode': 'CD',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 156,
#                 'NewDeaths': 4,
#                 'NewRecovered': 20,
#                 'Slug': 'congo-kinshasa',
#                 'TotalConfirmed': 2297,
#                 'TotalDeaths': 67,
#                 'TotalRecovered': 337},
#                {'Country': 'Costa Rica',
#                 'CountryCode': 'CR',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 21,
#                 'NewDeaths': 0,
#                 'NewRecovered': 8,
#                 'Slug': 'costa-rica',
#                 'TotalConfirmed': 951,
#                 'TotalDeaths': 10,
#                 'TotalRecovered': 628},
#                {'Country': 'Croatia',
#                 'CountryCode': 'HR',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 0,
#                 'NewDeaths': 1,
#                 'NewRecovered': 8,
#                 'Slug': 'croatia',
#                 'TotalConfirmed': 2244,
#                 'TotalDeaths': 100,
#                 'TotalRecovered': 2035},
#                {'Country': 'Cuba',
#                 'CountryCode': 'CU',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 6,
#                 'NewDeaths': 0,
#                 'NewRecovered': 15,
#                 'Slug': 'cuba',
#                 'TotalConfirmed': 1947,
#                 'TotalDeaths': 82,
#                 'TotalRecovered': 1704},
#                {'Country': 'Cyprus',
#                 'CountryCode': 'CY',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 2,
#                 'NewDeaths': 0,
#                 'NewRecovered': 0,
#                 'Slug': 'cyprus',
#                 'TotalConfirmed': 937,
#                 'TotalDeaths': 17,
#                 'TotalRecovered': 594},
#                {'Country': 'Czech Republic',
#                 'CountryCode': 'CZ',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 47,
#                 'NewDeaths': 2,
#                 'NewRecovered': 104,
#                 'Slug': 'czech-republic',
#                 'TotalConfirmed': 9002,
#                 'TotalDeaths': 317,
#                 'TotalRecovered': 6182},
#                {'Country': "Côte d'Ivoire",
#                 'CountryCode': 'CI',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 47,
#                 'NewDeaths': 0,
#                 'NewRecovered': 38,
#                 'Slug': 'cote-divoire',
#                 'TotalConfirmed': 2423,
#                 'TotalDeaths': 30,
#                 'TotalRecovered': 1257},
#                {'Country': 'Denmark',
#                 'CountryCode': 'DK',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 27,
#                 'NewDeaths': 1,
#                 'NewRecovered': 64,
#                 'Slug': 'denmark',
#                 'TotalConfirmed': 11586,
#                 'TotalDeaths': 563,
#                 'TotalRecovered': 10162},
#                {'Country': 'Djibouti',
#                 'CountryCode': 'DJ',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 198,
#                 'NewDeaths': 4,
#                 'NewRecovered': 15,
#                 'Slug': 'djibouti',
#                 'TotalConfirmed': 2468,
#                 'TotalDeaths': 14,
#                 'TotalRecovered': 1079},
#                {'Country': 'Dominica',
#                 'CountryCode': 'DM',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 0,
#                 'NewDeaths': 0,
#                 'NewRecovered': 0,
#                 'Slug': 'dominica',
#                 'TotalConfirmed': 16,
#                 'TotalDeaths': 0,
#                 'TotalRecovered': 16},
#                {'Country': 'Dominican Republic',
#                 'CountryCode': 'DO',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 272,
#                 'NewDeaths': 2,
#                 'NewRecovered': 152,
#                 'Slug': 'dominican-republic',
#                 'TotalConfirmed': 15073,
#                 'TotalDeaths': 460,
#                 'TotalRecovered': 8285},
#                {'Country': 'Ecuador',
#                 'CountryCode': 'EC',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 599,
#                 'NewDeaths': 95,
#                 'NewRecovered': 14443,
#                 'Slug': 'ecuador',
#                 'TotalConfirmed': 37355,
#                 'TotalDeaths': 3203,
#                 'TotalRecovered': 18003},
#                {'Country': 'Egypt',
#                 'CountryCode': 'EG',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 702,
#                 'NewDeaths': 19,
#                 'NewRecovered': 93,
#                 'Slug': 'egypt',
#                 'TotalConfirmed': 17967,
#                 'TotalDeaths': 783,
#                 'TotalRecovered': 4900},
#                {'Country': 'El Salvador',
#                 'CountryCode': 'SV',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 68,
#                 'NewDeaths': 0,
#                 'NewRecovered': 139,
#                 'Slug': 'el-salvador',
#                 'TotalConfirmed': 1983,
#                 'TotalDeaths': 35,
#                 'TotalRecovered': 772},
#                {'Country': 'Equatorial Guinea',
#                 'CountryCode': 'GQ',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 83,
#                 'NewDeaths': 1,
#                 'NewRecovered': 0,
#                 'Slug': 'equatorial-guinea',
#                 'TotalConfirmed': 1043,
#                 'TotalDeaths': 12,
#                 'TotalRecovered': 165},
#                {'Country': 'Eritrea',
#                 'CountryCode': 'ER',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 0,
#                 'NewDeaths': 0,
#                 'NewRecovered': 0,
#                 'Slug': 'eritrea',
#                 'TotalConfirmed': 39,
#                 'TotalDeaths': 0,
#                 'TotalRecovered': 39},
#                {'Country': 'Estonia',
#                 'CountryCode': 'EE',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 1,
#                 'NewDeaths': 1,
#                 'NewRecovered': 6,
#                 'Slug': 'estonia',
#                 'TotalConfirmed': 1824,
#                 'TotalDeaths': 65,
#                 'TotalRecovered': 1538},
#                {'Country': 'Ethiopia',
#                 'CountryCode': 'ET',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 73,
#                 'NewDeaths': 0,
#                 'NewRecovered': 7,
#                 'Slug': 'ethiopia',
#                 'TotalConfirmed': 655,
#                 'TotalDeaths': 5,
#                 'TotalRecovered': 159},
#                {'Country': 'Fiji',
#                 'CountryCode': 'FJ',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 0,
#                 'NewDeaths': 0,
#                 'NewRecovered': 0,
#                 'Slug': 'fiji',
#                 'TotalConfirmed': 18,
#                 'TotalDeaths': 0,
#                 'TotalRecovered': 15},
#                {'Country': 'Finland',
#                 'CountryCode': 'FI',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 20,
#                 'NewDeaths': 1,
#                 'NewRecovered': 300,
#                 'Slug': 'finland',
#                 'TotalConfirmed': 6599,
#                 'TotalDeaths': 308,
#                 'TotalRecovered': 5100},
#                {'Country': 'France',
#                 'CountryCode': 'FR',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 358,
#                 'NewDeaths': 90,
#                 'NewRecovered': 582,
#                 'Slug': 'france',
#                 'TotalConfirmed': 183067,
#                 'TotalDeaths': 28460,
#                 'TotalRecovered': 65317},
#                {'Country': 'Gabon',
#                 'CountryCode': 'GA',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 201,
#                 'NewDeaths': 2,
#                 'NewRecovered': 103,
#                 'Slug': 'gabon',
#                 'TotalConfirmed': 2135,
#                 'TotalDeaths': 14,
#                 'TotalRecovered': 562},
#                {'Country': 'Gambia',
#                 'CountryCode': 'GM',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 0,
#                 'NewDeaths': 0,
#                 'NewRecovered': 4,
#                 'Slug': 'gambia',
#                 'TotalConfirmed': 25,
#                 'TotalDeaths': 1,
#                 'TotalRecovered': 17},
#                {'Country': 'Georgia',
#                 'CountryCode': 'GE',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 1,
#                 'NewDeaths': 0,
#                 'NewRecovered': 4,
#                 'Slug': 'georgia',
#                 'TotalConfirmed': 731,
#                 'TotalDeaths': 12,
#                 'TotalRecovered': 526},
#                {'Country': 'Germany',
#                 'CountryCode': 'DE',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 272,
#                 'NewDeaths': 26,
#                 'NewRecovered': 918,
#                 'Slug': 'germany',
#                 'TotalConfirmed': 180600,
#                 'TotalDeaths': 8309,
#                 'TotalRecovered': 161199},
#                {'Country': 'Ghana',
#                 'CountryCode': 'GH',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 125,
#                 'NewDeaths': 0,
#                 'NewRecovered': 72,
#                 'Slug': 'ghana',
#                 'TotalConfirmed': 6808,
#                 'TotalDeaths': 32,
#                 'TotalRecovered': 2070},
#                {'Country': 'Greece',
#                 'CountryCode': 'GR',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 4,
#                 'NewDeaths': 1,
#                 'NewRecovered': 0,
#                 'Slug': 'greece',
#                 'TotalConfirmed': 2882,
#                 'TotalDeaths': 172,
#                 'TotalRecovered': 1374},
#                {'Country': 'Grenada',
#                 'CountryCode': 'GD',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 1,
#                 'NewDeaths': 0,
#                 'NewRecovered': 1,
#                 'Slug': 'grenada',
#                 'TotalConfirmed': 23,
#                 'TotalDeaths': 0,
#                 'TotalRecovered': 18},
#                {'Country': 'Guatemala',
#                 'CountryCode': 'GT',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 336,
#                 'NewDeaths': 1,
#                 'NewRecovered': 16,
#                 'Slug': 'guatemala',
#                 'TotalConfirmed': 3760,
#                 'TotalDeaths': 59,
#                 'TotalRecovered': 274},
#                {'Country': 'Guinea',
#                 'CountryCode': 'GN',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 0,
#                 'NewDeaths': 0,
#                 'NewRecovered': 0,
#                 'Slug': 'guinea',
#                 'TotalConfirmed': 3275,
#                 'TotalDeaths': 20,
#                 'TotalRecovered': 1673},
#                {'Country': 'Guinea-Bissau',
#                 'CountryCode': 'GW',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 64,
#                 'NewDeaths': 1,
#                 'NewRecovered': 0,
#                 'Slug': 'guinea-bissau',
#                 'TotalConfirmed': 1178,
#                 'TotalDeaths': 7,
#                 'TotalRecovered': 42},
#                {'Country': 'Guyana',
#                 'CountryCode': 'GY',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 2,
#                 'NewDeaths': 1,
#                 'NewRecovered': 0,
#                 'Slug': 'guyana',
#                 'TotalConfirmed': 137,
#                 'TotalDeaths': 11,
#                 'TotalRecovered': 62},
#                {'Country': 'Haiti',
#                 'CountryCode': 'HT',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 93,
#                 'NewDeaths': 1,
#                 'NewRecovered': 0,
#                 'Slug': 'haiti',
#                 'TotalConfirmed': 958,
#                 'TotalDeaths': 27,
#                 'TotalRecovered': 22},
#                {'Country': 'Holy See (Vatican City State)',
#                 'CountryCode': 'VA',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 0,
#                 'NewDeaths': 0,
#                 'NewRecovered': 0,
#                 'Slug': 'holy-see-vatican-city-state',
#                 'TotalConfirmed': 12,
#                 'TotalDeaths': 0,
#                 'TotalRecovered': 2},
#                {'Country': 'Honduras',
#                 'CountryCode': 'HN',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 239,
#                 'NewDeaths': 2,
#                 'NewRecovered': 5,
#                 'Slug': 'honduras',
#                 'TotalConfirmed': 4189,
#                 'TotalDeaths': 182,
#                 'TotalRecovered': 473},
#                {'Country': 'Hungary',
#                 'CountryCode': 'HU',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 15,
#                 'NewDeaths': 5,
#                 'NewRecovered': 21,
#                 'Slug': 'hungary',
#                 'TotalConfirmed': 3756,
#                 'TotalDeaths': 491,
#                 'TotalRecovered': 1711},
#                {'Country': 'Iceland',
#                 'CountryCode': 'IS',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 0,
#                 'NewDeaths': 0,
#                 'NewRecovered': 0,
#                 'Slug': 'iceland',
#                 'TotalConfirmed': 1804,
#                 'TotalDeaths': 10,
#                 'TotalRecovered': 1791},
#                {'Country': 'India',
#                 'CountryCode': 'IN',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 6414,
#                 'NewDeaths': 148,
#                 'NewRecovered': 3014,
#                 'Slug': 'india',
#                 'TotalConfirmed': 144950,
#                 'TotalDeaths': 4172,
#                 'TotalRecovered': 60706},
#                {'Country': 'Indonesia',
#                 'CountryCode': 'ID',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 479,
#                 'NewDeaths': 19,
#                 'NewRecovered': 240,
#                 'Slug': 'indonesia',
#                 'TotalConfirmed': 22750,
#                 'TotalDeaths': 1391,
#                 'TotalRecovered': 5642},
#                {'Country': 'Iran, Islamic Republic of',
#                 'CountryCode': 'IR',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 2023,
#                 'NewDeaths': 34,
#                 'NewRecovered': 1912,
#                 'Slug': 'iran',
#                 'TotalConfirmed': 137724,
#                 'TotalDeaths': 7451,
#                 'TotalRecovered': 107713},
#                {'Country': 'Iraq',
#                 'CountryCode': 'IQ',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 163,
#                 'NewDeaths': 3,
#                 'NewRecovered': 73,
#                 'Slug': 'iraq',
#                 'TotalConfirmed': 4632,
#                 'TotalDeaths': 163,
#                 'TotalRecovered': 2811},
#                {'Country': 'Ireland',
#                 'CountryCode': 'IE',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 59,
#                 'NewDeaths': 0,
#                 'NewRecovered': 0,
#                 'Slug': 'ireland',
#                 'TotalConfirmed': 24698,
#                 'TotalDeaths': 1608,
#                 'TotalRecovered': 21060},
#                {'Country': 'Israel',
#                 'CountryCode': 'IL',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 17,
#                 'NewDeaths': 2,
#                 'NewRecovered': 154,
#                 'Slug': 'israel',
#                 'TotalConfirmed': 16734,
#                 'TotalDeaths': 281,
#                 'TotalRecovered': 14307},
#                {'Country': 'Italy',
#                 'CountryCode': 'IT',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 300,
#                 'NewDeaths': 92,
#                 'NewRecovered': 1502,
#                 'Slug': 'italy',
#                 'TotalConfirmed': 230158,
#                 'TotalDeaths': 32877,
#                 'TotalRecovered': 141981},
#                {'Country': 'Jamaica',
#                 'CountryCode': 'JM',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 4,
#                 'NewDeaths': 0,
#                 'NewRecovered': 27,
#                 'Slug': 'jamaica',
#                 'TotalConfirmed': 556,
#                 'TotalDeaths': 9,
#                 'TotalRecovered': 238},
#                {'Country': 'Japan',
#                 'CountryCode': 'JP',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 31,
#                 'NewDeaths': 10,
#                 'NewRecovered': 199,
#                 'Slug': 'japan',
#                 'TotalConfirmed': 16581,
#                 'TotalDeaths': 830,
#                 'TotalRecovered': 13612},
#                {'Country': 'Jordan',
#                 'CountryCode': 'JO',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 3,
#                 'NewDeaths': 0,
#                 'NewRecovered': 8,
#                 'Slug': 'jordan',
#                 'TotalConfirmed': 711,
#                 'TotalDeaths': 9,
#                 'TotalRecovered': 479},
#                {'Country': 'Kazakhstan',
#                 'CountryCode': 'KZ',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 438,
#                 'NewDeaths': 0,
#                 'NewRecovered': 163,
#                 'Slug': 'kazakhstan',
#                 'TotalConfirmed': 8969,
#                 'TotalDeaths': 35,
#                 'TotalRecovered': 4515},
#                {'Country': 'Kenya',
#                 'CountryCode': 'KE',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 72,
#                 'NewDeaths': 1,
#                 'NewRecovered': 19,
#                 'Slug': 'kenya',
#                 'TotalConfirmed': 1286,
#                 'TotalDeaths': 52,
#                 'TotalRecovered': 402},
#                {'Country': 'Korea (South)',
#                 'CountryCode': 'KR',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 19,
#                 'NewDeaths': 2,
#                 'NewRecovered': 49,
#                 'Slug': 'korea-south',
#                 'TotalConfirmed': 11225,
#                 'TotalDeaths': 269,
#                 'TotalRecovered': 10275},
#                {'Country': 'Kuwait',
#                 'CountryCode': 'KW',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 665,
#                 'NewDeaths': 9,
#                 'NewRecovered': 504,
#                 'Slug': 'kuwait',
#                 'TotalConfirmed': 21967,
#                 'TotalDeaths': 165,
#                 'TotalRecovered': 6621},
#                {'Country': 'Kyrgyzstan',
#                 'CountryCode': 'KG',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 30,
#                 'NewDeaths': 2,
#                 'NewRecovered': 12,
#                 'Slug': 'kyrgyzstan',
#                 'TotalConfirmed': 1433,
#                 'TotalDeaths': 16,
#                 'TotalRecovered': 992},
#                {'Country': 'Lao PDR',
#                 'CountryCode': 'LA',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 0,
#                 'NewDeaths': 0,
#                 'NewRecovered': 0,
#                 'Slug': 'lao-pdr',
#                 'TotalConfirmed': 19,
#                 'TotalDeaths': 0,
#                 'TotalRecovered': 14},
#                {'Country': 'Latvia',
#                 'CountryCode': 'LV',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 2,
#                 'NewDeaths': 0,
#                 'NewRecovered': 0,
#                 'Slug': 'latvia',
#                 'TotalConfirmed': 1049,
#                 'TotalDeaths': 22,
#                 'TotalRecovered': 712},
#                {'Country': 'Lebanon',
#                 'CountryCode': 'LB',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 5,
#                 'NewDeaths': 0,
#                 'NewRecovered': 0,
#                 'Slug': 'lebanon',
#                 'TotalConfirmed': 1119,
#                 'TotalDeaths': 26,
#                 'TotalRecovered': 688},
#                {'Country': 'Lesotho',
#                 'CountryCode': 'LS',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 0,
#                 'NewDeaths': 0,
#                 'NewRecovered': 0,
#                 'Slug': 'lesotho',
#                 'TotalConfirmed': 2,
#                 'TotalDeaths': 0,
#                 'TotalRecovered': 0},
#                {'Country': 'Liberia',
#                 'CountryCode': 'LR',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 0,
#                 'NewDeaths': 0,
#                 'NewRecovered': 2,
#                 'Slug': 'liberia',
#                 'TotalConfirmed': 265,
#                 'TotalDeaths': 26,
#                 'TotalRecovered': 141},
#                {'Country': 'Libya',
#                 'CountryCode': 'LY',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 0,
#                 'NewDeaths': 0,
#                 'NewRecovered': 1,
#                 'Slug': 'libya',
#                 'TotalConfirmed': 75,
#                 'TotalDeaths': 3,
#                 'TotalRecovered': 40},
#                {'Country': 'Liechtenstein',
#                 'CountryCode': 'LI',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 0,
#                 'NewDeaths': 0,
#                 'NewRecovered': 0,
#                 'Slug': 'liechtenstein',
#                 'TotalConfirmed': 82,
#                 'TotalDeaths': 1,
#                 'TotalRecovered': 55},
#                {'Country': 'Lithuania',
#                 'CountryCode': 'LT',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 12,
#                 'NewDeaths': 0,
#                 'NewRecovered': 0,
#                 'Slug': 'lithuania',
#                 'TotalConfirmed': 1635,
#                 'TotalDeaths': 63,
#                 'TotalRecovered': 1138},
#                {'Country': 'Luxembourg',
#                 'CountryCode': 'LU',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 1,
#                 'NewDeaths': 0,
#                 'NewRecovered': 14,
#                 'Slug': 'luxembourg',
#                 'TotalConfirmed': 3993,
#                 'TotalDeaths': 110,
#                 'TotalRecovered': 3781},
#                {'Country': 'Macedonia, Republic of',
#                 'CountryCode': 'MK',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 21,
#                 'NewDeaths': 0,
#                 'NewRecovered': 17,
#                 'Slug': 'macedonia',
#                 'TotalConfirmed': 1999,
#                 'TotalDeaths': 113,
#                 'TotalRecovered': 1439},
#                {'Country': 'Madagascar',
#                 'CountryCode': 'MG',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 15,
#                 'NewDeaths': 0,
#                 'NewRecovered': 5,
#                 'Slug': 'madagascar',
#                 'TotalConfirmed': 542,
#                 'TotalDeaths': 2,
#                 'TotalRecovered': 147},
#                {'Country': 'Malawi',
#                 'CountryCode': 'MW',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 18,
#                 'NewDeaths': 0,
#                 'NewRecovered': 0,
#                 'Slug': 'malawi',
#                 'TotalConfirmed': 101,
#                 'TotalDeaths': 4,
#                 'TotalRecovered': 33},
#                {'Country': 'Malaysia',
#                 'CountryCode': 'MY',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 172,
#                 'NewDeaths': 0,
#                 'NewRecovered': 34,
#                 'Slug': 'malaysia',
#                 'TotalConfirmed': 7417,
#                 'TotalDeaths': 115,
#                 'TotalRecovered': 5979},
#                {'Country': 'Maldives',
#                 'CountryCode': 'MV',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 24,
#                 'NewDeaths': 0,
#                 'NewRecovered': 11,
#                 'Slug': 'maldives',
#                 'TotalConfirmed': 1395,
#                 'TotalDeaths': 4,
#                 'TotalRecovered': 155},
#                {'Country': 'Mali',
#                 'CountryCode': 'ML',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 29,
#                 'NewDeaths': 2,
#                 'NewRecovered': 7,
#                 'Slug': 'mali',
#                 'TotalConfirmed': 1059,
#                 'TotalDeaths': 67,
#                 'TotalRecovered': 604},
#                {'Country': 'Malta',
#                 'CountryCode': 'MT',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 1,
#                 'NewDeaths': 0,
#                 'NewRecovered': 9,
#                 'Slug': 'malta',
#                 'TotalConfirmed': 611,
#                 'TotalDeaths': 6,
#                 'TotalRecovered': 485},
#                {'Country': 'Mauritania',
#                 'CountryCode': 'MR',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 25,
#                 'NewDeaths': 3,
#                 'NewRecovered': 0,
#                 'Slug': 'mauritania',
#                 'TotalConfirmed': 262,
#                 'TotalDeaths': 9,
#                 'TotalRecovered': 15},
#                {'Country': 'Mauritius',
#                 'CountryCode': 'MU',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 0,
#                 'NewDeaths': 0,
#                 'NewRecovered': 0,
#                 'Slug': 'mauritius',
#                 'TotalConfirmed': 334,
#                 'TotalDeaths': 10,
#                 'TotalRecovered': 322},
#                {'Country': 'Mexico',
#                 'CountryCode': 'MX',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 2485,
#                 'NewDeaths': 239,
#                 'NewRecovered': 2473,
#                 'Slug': 'mexico',
#                 'TotalConfirmed': 71105,
#                 'TotalDeaths': 7633,
#                 'TotalRecovered': 49452},
#                {'Country': 'Moldova',
#                 'CountryCode': 'MD',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 54,
#                 'NewDeaths': 11,
#                 'NewRecovered': 89,
#                 'Slug': 'moldova',
#                 'TotalConfirmed': 7147,
#                 'TotalDeaths': 261,
#                 'TotalRecovered': 3802},
#                {'Country': 'Monaco',
#                 'CountryCode': 'MC',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 0,
#                 'NewDeaths': 0,
#                 'NewRecovered': 0,
#                 'Slug': 'monaco',
#                 'TotalConfirmed': 98,
#                 'TotalDeaths': 4,
#                 'TotalRecovered': 90},
#                {'Country': 'Mongolia',
#                 'CountryCode': 'MN',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 0,
#                 'NewDeaths': 0,
#                 'NewRecovered': 1,
#                 'Slug': 'mongolia',
#                 'TotalConfirmed': 141,
#                 'TotalDeaths': 0,
#                 'TotalRecovered': 33},
#                {'Country': 'Montenegro',
#                 'CountryCode': 'ME',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 0,
#                 'NewDeaths': 0,
#                 'NewRecovered': 0,
#                 'Slug': 'montenegro',
#                 'TotalConfirmed': 324,
#                 'TotalDeaths': 9,
#                 'TotalRecovered': 315},
#                {'Country': 'Morocco',
#                 'CountryCode': 'MA',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 99,
#                 'NewDeaths': 1,
#                 'NewRecovered': 71,
#                 'Slug': 'morocco',
#                 'TotalConfirmed': 7532,
#                 'TotalDeaths': 200,
#                 'TotalRecovered': 4774},
#                {'Country': 'Mozambique',
#                 'CountryCode': 'MZ',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 15,
#                 'NewDeaths': 1,
#                 'NewRecovered': 20,
#                 'Slug': 'mozambique',
#                 'TotalConfirmed': 209,
#                 'TotalDeaths': 1,
#                 'TotalRecovered': 71},
#                {'Country': 'Myanmar',
#                 'CountryCode': 'MM',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 2,
#                 'NewDeaths': 0,
#                 'NewRecovered': 1,
#                 'Slug': 'myanmar',
#                 'TotalConfirmed': 203,
#                 'TotalDeaths': 6,
#                 'TotalRecovered': 123},
#                {'Country': 'Namibia',
#                 'CountryCode': 'NA',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 0,
#                 'NewDeaths': 0,
#                 'NewRecovered': 0,
#                 'Slug': 'namibia',
#                 'TotalConfirmed': 21,
#                 'TotalDeaths': 0,
#                 'TotalRecovered': 14},
#                {'Country': 'Nepal',
#                 'CountryCode': 'NP',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 79,
#                 'NewDeaths': 1,
#                 'NewRecovered': 25,
#                 'Slug': 'nepal',
#                 'TotalConfirmed': 682,
#                 'TotalDeaths': 4,
#                 'TotalRecovered': 112},
#                {'Country': 'Netherlands',
#                 'CountryCode': 'NL',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 210,
#                 'NewDeaths': 8,
#                 'NewRecovered': 0,
#                 'Slug': 'netherlands',
#                 'TotalConfirmed': 45647,
#                 'TotalDeaths': 5849,
#                 'TotalRecovered': 174},
#                {'Country': 'New Zealand',
#                 'CountryCode': 'NZ',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 0,
#                 'NewDeaths': 0,
#                 'NewRecovered': 5,
#                 'Slug': 'new-zealand',
#                 'TotalConfirmed': 1504,
#                 'TotalDeaths': 21,
#                 'TotalRecovered': 1461},
#                {'Country': 'Nicaragua',
#                 'CountryCode': 'NI',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 0,
#                 'NewDeaths': 0,
#                 'NewRecovered': 0,
#                 'Slug': 'nicaragua',
#                 'TotalConfirmed': 279,
#                 'TotalDeaths': 17,
#                 'TotalRecovered': 199},
#                {'Country': 'Niger',
#                 'CountryCode': 'NE',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 6,
#                 'NewDeaths': 1,
#                 'NewRecovered': 3,
#                 'Slug': 'niger',
#                 'TotalConfirmed': 951,
#                 'TotalDeaths': 62,
#                 'TotalRecovered': 786},
#                {'Country': 'Nigeria',
#                 'CountryCode': 'NG',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 229,
#                 'NewDeaths': 7,
#                 'NewRecovered': 48,
#                 'Slug': 'nigeria',
#                 'TotalConfirmed': 8068,
#                 'TotalDeaths': 233,
#                 'TotalRecovered': 2311},
#                {'Country': 'Norway',
#                 'CountryCode': 'NO',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 12,
#                 'NewDeaths': 0,
#                 'NewRecovered': 0,
#                 'Slug': 'norway',
#                 'TotalConfirmed': 8364,
#                 'TotalDeaths': 235,
#                 'TotalRecovered': 7727},
#                {'Country': 'Oman',
#                 'CountryCode': 'OM',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 0,
#                 'NewDeaths': 0,
#                 'NewRecovered': 0,
#                 'Slug': 'oman',
#                 'TotalConfirmed': 7770,
#                 'TotalDeaths': 37,
#                 'TotalRecovered': 1933},
#                {'Country': 'Pakistan',
#                 'CountryCode': 'PK',
#                 'Date': '2020-05-27T04:16:31Z',
# ...
#                {'Country': 'Saudi Arabia',
#                 'CountryCode': 'SA',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 2235,
#                 'NewDeaths': 9,
#                 'NewRecovered': 2148,
#                 'Slug': 'saudi-arabia',
#                 'TotalConfirmed': 74795,
#                 'TotalDeaths': 399,
#                 'TotalRecovered': 45668},
#                {'Country': 'Senegal',
#                 'CountryCode': 'SN',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 83,
#                 'NewDeaths': 0,
#                 'NewRecovered': 59,
#                 'Slug': 'senegal',
#                 'TotalConfirmed': 3130,
#                 'TotalDeaths': 35,
#                 'TotalRecovered': 1515},
#                {'Country': 'Serbia',
#                 'CountryCode': 'RS',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 34,
#                 'NewDeaths': 1,
#                 'NewRecovered': 63,
#                 'Slug': 'serbia',
#                 'TotalConfirmed': 11193,
#                 'TotalDeaths': 239,
#                 'TotalRecovered': 5920},
#                {'Country': 'Seychelles',
#                 'CountryCode': 'SC',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 0,
#                 'NewDeaths': 0,
#                 'NewRecovered': 0,
#                 'Slug': 'seychelles',
#                 'TotalConfirmed': 11,
#                 'TotalDeaths': 0,
#                 'TotalRecovered': 11},
#                {'Country': 'Sierra Leone',
#                 'CountryCode': 'SL',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 28,
#                 'NewDeaths': 2,
#                 'NewRecovered': 52,
#                 'Slug': 'sierra-leone',
#                 'TotalConfirmed': 735,
#                 'TotalDeaths': 42,
#                 'TotalRecovered': 293},
#                {'Country': 'Singapore',
#                 'CountryCode': 'SG',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 344,
#                 'NewDeaths': 0,
#                 'NewRecovered': 862,
#                 'Slug': 'singapore',
#                 'TotalConfirmed': 31960,
#                 'TotalDeaths': 23,
#                 'TotalRecovered': 15738},
#                {'Country': 'Slovakia',
#                 'CountryCode': 'SK',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 2,
#                 'NewDeaths': 0,
#                 'NewRecovered': 6,
#                 'Slug': 'slovakia',
#                 'TotalConfirmed': 1511,
#                 'TotalDeaths': 28,
#                 'TotalRecovered': 1307},
#                {'Country': 'Slovenia',
#                 'CountryCode': 'SI',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 1,
#                 'NewDeaths': 0,
#                 'NewRecovered': 6,
#                 'Slug': 'slovenia',
#                 'TotalConfirmed': 1469,
#                 'TotalDeaths': 107,
#                 'TotalRecovered': 1346},
#                {'Country': 'Somalia',
#                 'CountryCode': 'SO',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 95,
#                 'NewDeaths': 5,
#                 'NewRecovered': 31,
#                 'Slug': 'somalia',
#                 'TotalConfirmed': 1689,
#                 'TotalDeaths': 66,
#                 'TotalRecovered': 235},
#                {'Country': 'South Africa',
#                 'CountryCode': 'ZA',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 1032,
#                 'NewDeaths': 52,
#                 'NewRecovered': 817,
#                 'Slug': 'south-africa',
#                 'TotalConfirmed': 23615,
#                 'TotalDeaths': 481,
#                 'TotalRecovered': 11917},
#                {'Country': 'South Sudan',
#                 'CountryCode': 'SS',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 151,
#                 'NewDeaths': 0,
#                 'NewRecovered': 0,
#                 'Slug': 'south-sudan',
#                 'TotalConfirmed': 806,
#                 'TotalDeaths': 8,
#                 'TotalRecovered': 6},
#                {'Country': 'Spain',
#                 'CountryCode': 'ES',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 0,
#                 'NewDeaths': 0,
#                 'NewRecovered': 0,
#                 'Slug': 'spain',
#                 'TotalConfirmed': 235772,
#                 'TotalDeaths': 28752,
#                 'TotalRecovered': 150376},
#                {'Country': 'Sri Lanka',
#                 'CountryCode': 'LK',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 41,
#                 'NewDeaths': 1,
#                 'NewRecovered': 21,
#                 'Slug': 'sri-lanka',
#                 'TotalConfirmed': 1182,
#                 'TotalDeaths': 10,
#                 'TotalRecovered': 695},
#                {'Country': 'Sudan',
#                 'CountryCode': 'SD',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 156,
#                 'NewDeaths': 5,
#                 'NewRecovered': 45,
#                 'Slug': 'sudan',
#                 'TotalConfirmed': 3976,
#                 'TotalDeaths': 170,
#                 'TotalRecovered': 503},
#                {'Country': 'Suriname',
#                 'CountryCode': 'SR',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 0,
#                 'NewDeaths': 0,
#                 'NewRecovered': 0,
#                 'Slug': 'suriname',
#                 'TotalConfirmed': 11,
#                 'TotalDeaths': 1,
#                 'TotalRecovered': 9},
#                {'Country': 'Swaziland',
#                 'CountryCode': 'SZ',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 6,
#                 'NewDeaths': 0,
#                 'NewRecovered': 2,
#                 'Slug': 'swaziland',
#                 'TotalConfirmed': 256,
#                 'TotalDeaths': 2,
#                 'TotalRecovered': 158},
#                {'Country': 'Sweden',
#                 'CountryCode': 'SE',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 384,
#                 'NewDeaths': 31,
#                 'NewRecovered': 0,
#                 'Slug': 'sweden',
#                 'TotalConfirmed': 33843,
#                 'TotalDeaths': 4029,
#                 'TotalRecovered': 4971},
#                {'Country': 'Switzerland',
#                 'CountryCode': 'CH',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 10,
#                 'NewDeaths': 7,
#                 'NewRecovered': 100,
#                 'Slug': 'switzerland',
#                 'TotalConfirmed': 30746,
#                 'TotalDeaths': 1913,
#                 'TotalRecovered': 28200},
#                {'Country': 'Syrian Arab Republic (Syria)',
#                 'CountryCode': 'SY',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 20,
#                 'NewDeaths': 0,
#                 'NewRecovered': 0,
#                 'Slug': 'syria',
#                 'TotalConfirmed': 106,
#                 'TotalDeaths': 4,
#                 'TotalRecovered': 41},
#                {'Country': 'Taiwan, Republic of China',
#                 'CountryCode': 'TW',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 0,
#                 'NewDeaths': 0,
#                 'NewRecovered': 1,
#                 'Slug': 'taiwan',
#                 'TotalConfirmed': 441,
#                 'TotalDeaths': 7,
#                 'TotalRecovered': 415},
#                {'Country': 'Tajikistan',
#                 'CountryCode': 'TJ',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 171,
#                 'NewDeaths': 0,
#                 'NewRecovered': 94,
#                 'Slug': 'tajikistan',
#                 'TotalConfirmed': 3100,
#                 'TotalDeaths': 46,
#                 'TotalRecovered': 1395},
#                {'Country': 'Tanzania, United Republic of',
#                 'CountryCode': 'TZ',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 0,
#                 'NewDeaths': 0,
#                 'NewRecovered': 0,
#                 'Slug': 'tanzania',
#                 'TotalConfirmed': 509,
#                 'TotalDeaths': 21,
#                 'TotalRecovered': 183},
#                {'Country': 'Thailand',
#                 'CountryCode': 'TH',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 2,
#                 'NewDeaths': 1,
#                 'NewRecovered': 7,
#                 'Slug': 'thailand',
#                 'TotalConfirmed': 3042,
#                 'TotalDeaths': 57,
#                 'TotalRecovered': 2928},
#                {'Country': 'Timor-Leste',
#                 'CountryCode': 'TL',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 0,
#                 'NewDeaths': 0,
#                 'NewRecovered': 0,
#                 'Slug': 'timor-leste',
#                 'TotalConfirmed': 24,
#                 'TotalDeaths': 0,
#                 'TotalRecovered': 24},
#                {'Country': 'Togo',
#                 'CountryCode': 'TG',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 5,
#                 'NewDeaths': 1,
#                 'NewRecovered': 20,
#                 'Slug': 'togo',
#                 'TotalConfirmed': 386,
#                 'TotalDeaths': 13,
#                 'TotalRecovered': 161},
#                {'Country': 'Trinidad and Tobago',
#                 'CountryCode': 'TT',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 0,
#                 'NewDeaths': 0,
#                 'NewRecovered': 0,
#                 'Slug': 'trinidad-and-tobago',
#                 'TotalConfirmed': 116,
#                 'TotalDeaths': 8,
#                 'TotalRecovered': 108},
#                {'Country': 'Tunisia',
#                 'CountryCode': 'TN',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 0,
#                 'NewDeaths': 0,
#                 'NewRecovered': 2,
#                 'Slug': 'tunisia',
#                 'TotalConfirmed': 1051,
#                 'TotalDeaths': 48,
#                 'TotalRecovered': 919},
#                {'Country': 'Turkey',
#                 'CountryCode': 'TR',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 987,
#                 'NewDeaths': 29,
#                 'NewRecovered': 1321,
#                 'Slug': 'turkey',
#                 'TotalConfirmed': 157814,
#                 'TotalDeaths': 4369,
#                 'TotalRecovered': 120015},
#                {'Country': 'Uganda',
#                 'CountryCode': 'UG',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 24,
#                 'NewDeaths': 0,
#                 'NewRecovered': 1,
#                 'Slug': 'uganda',
#                 'TotalConfirmed': 222,
#                 'TotalDeaths': 0,
#                 'TotalRecovered': 69},
#                {'Country': 'Ukraine',
#                 'CountryCode': 'UA',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 259,
#                 'NewDeaths': 6,
#                 'NewRecovered': 126,
#                 'Slug': 'ukraine',
#                 'TotalConfirmed': 21245,
#                 'TotalDeaths': 623,
#                 'TotalRecovered': 7234},
#                {'Country': 'United Arab Emirates',
#                 'CountryCode': 'AE',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 822,
#                 'NewDeaths': 3,
#                 'NewRecovered': 601,
#                 'Slug': 'united-arab-emirates',
#                 'TotalConfirmed': 30307,
#                 'TotalDeaths': 248,
#                 'TotalRecovered': 15657},
#                {'Country': 'United Kingdom',
#                 'CountryCode': 'GB',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 1631,
#                 'NewDeaths': 121,
#                 'NewRecovered': 10,
#                 'Slug': 'united-kingdom',
#                 'TotalConfirmed': 262547,
#                 'TotalDeaths': 36996,
#                 'TotalRecovered': 1161},
#                {'Country': 'United States of America',
#                 'CountryCode': 'US',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 19056,
#                 'NewDeaths': 500,
#                 'NewRecovered': 12421,
#                 'Slug': 'united-states',
#                 'TotalConfirmed': 1662302,
#                 'TotalDeaths': 98220,
#                 'TotalRecovered': 379157},
#                {'Country': 'Uruguay',
#                 'CountryCode': 'UY',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 18,
#                 'NewDeaths': 0,
#                 'NewRecovered': 11,
#                 'Slug': 'uruguay',
#                 'TotalConfirmed': 787,
#                 'TotalDeaths': 22,
#                 'TotalRecovered': 629},
#                {'Country': 'Uzbekistan',
#                 'CountryCode': 'UZ',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 25,
#                 'NewDeaths': 0,
#                 'NewRecovered': 42,
#                 'Slug': 'uzbekistan',
#                 'TotalConfirmed': 3189,
#                 'TotalDeaths': 13,
#                 'TotalRecovered': 2607},
#                {'Country': 'Venezuela (Bolivarian Republic)',
#                 'CountryCode': 'VE',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 56,
#                 'NewDeaths': 0,
#                 'NewRecovered': 40,
#                 'Slug': 'venezuela',
#                 'TotalConfirmed': 1177,
#                 'TotalDeaths': 10,
#                 'TotalRecovered': 302},
#                {'Country': 'Viet Nam',
#                 'CountryCode': 'VN',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 1,
#                 'NewDeaths': 0,
#                 'NewRecovered': 5,
#                 'Slug': 'vietnam',
#                 'TotalConfirmed': 326,
#                 'TotalDeaths': 0,
#                 'TotalRecovered': 272},
#                {'Country': 'Western Sahara',
#                 'CountryCode': 'EH',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 0,
#                 'NewDeaths': 0,
#                 'NewRecovered': 0,
#                 'Slug': 'western-sahara',
#                 'TotalConfirmed': 9,
#                 'TotalDeaths': 0,
#                 'TotalRecovered': 6},
#                {'Country': 'Yemen',
#                 'CountryCode': 'YE',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 11,
#                 'NewDeaths': 2,
#                 'NewRecovered': 0,
#                 'Slug': 'yemen',
#                 'TotalConfirmed': 233,
#                 'TotalDeaths': 44,
#                 'TotalRecovered': 10},
#                {'Country': 'Zambia',
#                 'CountryCode': 'ZM',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 0,
#                 'NewDeaths': 0,
#                 'NewRecovered': 0,
#                 'Slug': 'zambia',
#                 'TotalConfirmed': 920,
#                 'TotalDeaths': 7,
#                 'TotalRecovered': 336},
#                {'Country': 'Zimbabwe',
#                 'CountryCode': 'ZW',
#                 'Date': '2020-05-27T04:16:31Z',
#                 'NewConfirmed': 0,
#                 'NewDeaths': 0,
#                 'NewRecovered': 0,
#                 'Slug': 'zimbabwe',
#                 'TotalConfirmed': 56,
#                 'TotalDeaths': 4,
#                 'TotalRecovered': 25}],
#  'Date': '2020-05-27T04:16:31Z',
#  'Global': {'NewConfirmed': 88833,
#             'NewDeaths': 3214,
#             'NewRecovered': 63212,
#             'TotalConfirmed': 5581829,
#             'TotalDeaths': 354790,
#             'TotalRecovered': 2231124}}

# %%
# Used to look for 'Country', 'TotalConfirmed', 'TotalDeaths' 'TotalRecovered'
data_json['Countries'][1]
# Out:
# {'Country': 'Albania',
#  'CountryCode': 'AL',
#  'Slug': 'albania',
#  'NewConfirmed': 6,
#  'TotalConfirmed': 1004,
#  'NewDeaths': 0,
#  'TotalDeaths': 32,
#  'NewRecovered': 6,
#  'TotalRecovered': 795,
#  'Date': '2020-05-27T04:16:31Z'}

# %%
# Getting the length of the request
len(data_json['Countries'])
# Out:
# 186

# %%
# Creating lists to loop through the json request and append the data
countries = []
total_cases = []
total_deaths = []
total_recover = []

for x in range(len(data_json['Countries'])):
    countries.append(data_json['Countries'][x]['Country'])
    total_cases.append(data_json['Countries'][x]['TotalConfirmed'])
    total_deaths.append(data_json['Countries'][x]['TotalDeaths'])
    total_recover.append(data_json['Countries'][x]['NewRecovered'])

# %%
# Creating a DataFrame to store the data
covid_dict = {
    "Country":countries,
    "Total_Cases":total_cases,
    "Total_Deaths":total_deaths,
    "Total_Recovered":total_recover
}
covid_df = pd.DataFrame(covid_dict)
covid_df
# Out:
#             Country  Total_Cases  Total_Deaths  Total_Recovered
# 0       Afghanistan        11173           219               22
# 1           Albania         1004            32                6
# 2           Algeria         8503           609                0
# 3           Andorra          763            51               10
# 4            Angola           70             4                0
# ..              ...          ...           ...              ...
# 181        Viet Nam          326             0                5
# 182  Western Sahara            9             0                0
# 183           Yemen          233            44                0
# 184          Zambia          920             7                0
# 185        Zimbabwe           56             4                0
#
# [186 rows x 4 columns]

# %% [markdown]
# ## COVID-19 Fundings

# %%
# Query data from the CDC JSON
url = 'https://data.cdc.gov/api/views/b58h-s9zx/rows.json?accessType=DOWNLOAD'
data_json = requests.get(url).json()
pprint(data_json)
# Out:
# {'data': [['row-ynus.gjgi~vu28',
#            '00000000-0000-0000-2EBE-A4D48EDEDBA8',
#            0,
#            1588945919,
#            None,
#            1588945919,
#            None,
#            '{ }',
#            'Long Island Jewish Medical Center',
#            'New Hyde Park',
#            'NY',
#            '$   277,653,312.42'],
#           ['row-y6k9_bee4_hs8w',
#            '00000000-0000-0000-AABE-087675FFE3D2',
#            0,
#            1588945919,
#            None,
#            1588945919,
#            None,
#            '{ }',
#            'Holy Name Medical Center (AKA Holy Name Health)',
#            'Teaneck',
#            'NJ',
#            '$   213,428,946.86'],
#           ['row-mjuv-vsfv_eean',
#            '00000000-0000-0000-286B-8BBBB25EAE74',
#            0,
#            1588945919,
#            None,
#            1588945919,
#            None,
#            '{ }',
#            'Tisch Hospital',
#            'New York',
#            'NY',
#            '$   203,180,446.74'],
#           ['row-3bbe_rwjk~yesc',
#            '00000000-0000-0000-52CE-BA5877CBE5E7',
#            0,
#            1588945919,
#            None,
#            1588945919,
#            None,
#            '{ }',
#            'NewYork-Presbyterian Queens',
#            'Flushing',
#            'NY',
#            '$   143,251,512.11'],
#           ['row-dxxt-7akb-8xww',
#            '00000000-0000-0000-F116-716033287C55',
#            0,
#            1588945919,
#            None,
#            1588945919,
#            None,
#            '{ }',
#            'Montefiore Hospital - Moses Campus',
#            'Bronx',
#            'NY',
#            '$   156,708,591.59'],
#           ['row-6r7d_fijz-udqj',
#            '00000000-0000-0000-0B3E-469C4BCDBB5A',
#            0,
#            1588945919,
#            None,
#            1588945919,
#            None,
#            '{ }',
#            'Sandra Atlas Bass Heart Hospital at North Shore University '
#            'Hospital',
#            'Manhasset',
#            'NY',
#            '$   137,531,542.64'],
#           ['row-fu7i-wew9-6gdb',
#            '00000000-0000-0000-2BB5-7CE8F8060FC8',
#            0,
#            1588945919,
#            None,
#            1588945919,
#            None,
#            '{ }',
#            'Mount Sinai Medical Center (AKA the Mount Sinai Hospital)',
#            'New York',
#            'NY',
#            '$   140,754,860.74'],
#           ['row-rd7i_nq98_yrgm',
#            '00000000-0000-0000-7AEC-A022E55CEAA3',
#            0,
#            1588945919,
#            None,
#            1588945919,
#            None,
#            '{ }',
#            'NewYork-Presbyterian/Columbia University Irving Medical Center',
#            'New York',
#            'NY',
#            '$   152,747,325.41'],
#           ['row-uyws.cgi9.hh87',
#            '00000000-0000-0000-E923-37BD6CF523F2',
#            0,
#            1588945919,
#            None,
#            1588945919,
#            None,
#            '{ }',
#            'Maimonides Medical Center',
#            'Brooklyn',
#            'NY',
#            '$   131,500,615.31'],
#           ['row-t72i.g7z6~h9jp',
#            '00000000-0000-0000-99E5-E4895E90545D',
#            0,
#            1588945919,
#            None,
#            1588945919,
#            None,
#            '{ }',
#            'NYC Health and Hospitals - Elmhurst (FKA Elmhurst Hospital Center)',
#            'Elmhurst',
#            'NY',
#            '$   111,346,403.33'],
#           ['row-uc9m_7873_y7ev',
#            '00000000-0000-0000-D9EE-92459EA2726E',
#            0,
#            1588945919,
#            None,
#            1588945919,
#            None,
#            '{ }',
#            'Hackensack University Medical Center',
#            'Hackensack',
#            'NJ',
#            '$   98,138,111.89'],
#           ['row-fb6r.qmrm~sp76',
#            '00000000-0000-0000-1724-50B4DEC247E2',
#            0,
#            1588945919,
#            None,
#            1588945919,
#            None,
#            '{ }',
#            'Ochsner Medical Center - West Bank Campus',
#            'Gretna',
#            'LA',
#            '$   91,279,199.85'],
#           ['row-j8xe.xmxa~j346',
#            '00000000-0000-0000-B17A-85ECD75E4A87',
#            0,
#            1588945919,
#            None,
#            1588945919,
#            None,
#            '{ }',
#            'Staten Island University Hospital - South Campus',
#            'Staten Island',
#            'NY',
#            '$   91,357,433.79'],
#           ['row-huba~qntd-6q95',
#            '00000000-0000-0000-8B33-D3BB6BC7678E',
#            0,
#            1588945919,
#            None,
#            1588945919,
#            None,
#            '{ }',
#            'NewYork-Presbyterian/Weill Cornell Medical Center',
#            'New York',
#            'NY',
#            '$   118,647,056.76'],
#           ['row-jdrt~98yv~tpmb',
#            '00000000-0000-0000-3D02-C25B2824ECFC',
#            0,
#            1588945919,
#            None,
#            1588945919,
#            None,
#            '{ }',
#            'BronxCare Hospital Center - Fulton Campus',
#            'Bronx',
#            'NY',
#            '$   91,535,709.54'],
#           ['row-k69i~szgu~i96t',
#            '00000000-0000-0000-3E05-F5354A9484BA',
#            0,
#            1588945919,
#            None,
#            1588945919,
#            None,
#            '{ }',
#            'NYU Winthrop Hospital (FKA Winthrop University Hospital)',
#            'Mineola',
#            'NY',
#            '$   108,038,387.94'],
#           ['row-ivbg.7iqc~dghk',
#            '00000000-0000-0000-506B-E04AAFEE5F56',
#            0,
#            1588945919,
#            None,
#            1588945919,
#            None,
#            '{ }',
#            'NewYork-Presbyterian Brooklyn Methodist Hospital (FKA New York '
#            'Methodist Hospital)',
#            'Brooklyn',
#            'NY',
#            '$   86,952,150.88'],
#           ['row-vjfr-wumh.hqq7',
#            '00000000-0000-0000-B70C-1875E5340177',
#            0,
#            1588945919,
#            None,
#            1588945919,
#            None,
#            '{ }',
#            'St Josephs University Medical Center (FKA St Josephs Regional '
#            'Medical Center)',
#            'Paterson',
#            'NJ',
#            '$   88,159,157.24'],
#           ['row-brgh~atbr-4d7g',
#            '00000000-0000-0000-D9E3-D32C96F34DD4',
#            0,
#            1588945919,
#            None,
#            1588945919,
#            None,
#            '{ }',
#            'NYC Health and Hospitals - Bellevue (FKA Bellevue Hospital Center)',
#            'New York',
#            'NY',
#            '$   86,705,275.60'],
#           ['row-495q-2tac~3yqf',
#            '00000000-0000-0000-838D-7E7CD76D5F43',
#            0,
#            1588945919,
#            None,
#            1588945919,
#            None,
#            '{ }',
#            'Jamaica Hospital Medical Center',
#            'Jamaica',
#            'NY',
#            '$   75,862,417.90'],
#           ['row-df9f~sw6c~4vgm',
#            '00000000-0000-0000-7971-356E888E6CE9',
#            0,
#            1588945919,
#            None,
#            1588945919,
#            None,
#            '{ }',
#            'Stony Brook University Hospital',
#            'Stony Brook',
#            'NY',
#            '$   83,300,041.29'],
#           ['row-9awh.ziw6_svjq',
#            '00000000-0000-0000-B551-A0C8EBE8845F',
#            0,
#            1588945919,
#            None,
#            1588945919,
#            None,
#            '{ }',
#            'NuHealth - Nassau University Medical Center',
#            'East Meadow',
#            'NY',
#            '$   75,340,417.34'],
#           ['row-5zb3-d2i7.4mjq',
#            '00000000-0000-0000-BF1F-90F78DD9D291',
#            0,
#            1588945919,
#            None,
#            1588945919,
#            None,
#            '{ }',
#            'NYC Health and Hospitals - Lincoln (FKA Lincoln Medical & Mental '
#            'Health Center)',
#            'Bronx',
#            'NY',
#            '$   76,138,987.53'],
#           ['row-4hx4_fqd8.z5ux',
#            '00000000-0000-0000-E831-AFD78DF0A7C4',
#            0,
#            1588945919,
#            None,
#            1588945919,
#            None,
#            '{ }',
#            'NYC Health and Hospitals - Kings County (FKA Kings County Hospital '
#            'Center)',
#            'Brooklyn',
#            'NY',
#            '$   78,931,188.49'],
#           ['row-5b38_m2tp~n4uq',
#            '00000000-0000-0000-74E2-7E09F505A234',
#            0,
#            1588945919,
#            None,
#            1588945919,
#            None,
#            '{ }',
#            'Montefiore Hospital - Einstein Campus (AKA Jack D Weiler Hospital)',
#            'Bronx',
#            'NY',
#            '$   89,200,836.28'],
#           ['row-xq52.uakt_7s3p',
#            '00000000-0000-0000-FA5B-CA52E24FC01D',
#            0,
#            1588945919,
#            None,
#            1588945919,
#            None,
#            '{ }',
#            'NYC Health and Hospitals - Jacobi (FKA Jacobi Medical Center)',
#            'Bronx',
#            'NY',
#            '$   75,309,433.06'],
#           ['row-iuga_t6ug.6pex',
#            '00000000-0000-0000-FDC5-E3CDD32C7D04',
#            0,
#            1588945919,
#            None,
#            1588945919,
#            None,
#            '{ }',
#            'Saint Barnabas Medical Center',
#            'Livingston',
#            'NJ',
#            '$   69,678,116.81'],
#           ['row-csvi-srrx.3cb9',
#            '00000000-0000-0000-6030-D0AE126A9B86',
#            0,
#            1588945919,
#            None,
#            1588945919,
#            None,
#            '{ }',
#            'White Plains Hospital',
#            'White Plains',
#            'NY',
#            '$   65,283,067.19'],
#           ['row-pif8~gcxy.jse9',
#            '00000000-0000-0000-7773-FE729D116A48',
#            0,
#            1588945919,
#            None,
#            1588945919,
#            None,
#            '{ }',
#            'Beaumont Hospital - Royal Oak',
#            'Royal Oak',
#            'MI',
#            '$   68,677,463.16'],
#           ['row-bafm_hxcu~qzz7',
#            '00000000-0000-0000-1385-3DA6CA5B88C9',
#            0,
#            1588945919,
#            None,
#            1588945919,
#            None,
#            '{ }',
#            'Lenox Hill Hospital',
#            'New York',
#            'NY',
#            '$   66,453,550.17'],
#           ['row-cu4e_243t-fz88',
#            '00000000-0000-0000-6B23-546BF80DE3BC',
#            0,
#            1588945919,
#            None,
#            1588945919,
#            None,
#            '{ }',
#            'Mount Sinai South Nassau (FKA South Nassau Communities Hospital)',
#            'Oceanside',
#            'NY',
#            '$   64,596,068.93'],
#           ['row-jhq8_np4q_bvj8',
#            '00000000-0000-0000-F8DD-143B17D78072',
#            0,
#            1588945919,
#            None,
#            1588945919,
#            None,
#            '{ }',
#            'Henry Ford Hospital',
#            'Detroit',
#            'MI',
#            '$   71,236,299.82'],
#           ['row-k64j.pq66_vdig',
#            '00000000-0000-0000-E06C-B99D589D95B4',
#            0,
#            1588945919,
#            None,
#            1588945919,
#            None,
#            '{ }',
#            'Brookdale Hospital Medical Center',
#            'Brooklyn',
#            'NY',
#            '$   66,309,962.02'],
#           ['row-2g9v_e4re-rwpc',
#            '00000000-0000-0000-1833-DD3DD710AA51',
#            0,
#            1588945919,
#            None,
#            1588945919,
#            None,
#            '{ }',
#            'NYC Health and Hospitals - Queens (FKA Queens Hospital Center)',
#            'Jamaica',
#            'NY',
#            '$   66,414,763.53'],
#           ['row-tpgc.g5ts-krmq',
#            '00000000-0000-0000-4A46-ED30C6DBBDD7',
#            0,
#            1588945919,
#            None,
#            1588945919,
#            None,
#            '{ }',
#            'JFK Medical Center',
#            'Edison',
#            'NJ',
#            '$   59,603,910.03'],
#           ['row-9iqr-j2uh.b8pv',
#            '00000000-0000-0000-324E-7C579E013B8B',
#            0,
#            1588945919,
#            None,
#            1588945919,
#            None,
#            '{ }',
#            'Wyckoff Heights Medical Center',
#            'Brooklyn',
#            'NY',
#            '$   59,878,470.75'],
#           ['row-g5n2_zzcp-nup2',
#            '00000000-0000-0000-D625-493585C5B8B9',
#            0,
#            1588945919,
#            None,
#            1588945919,
#            None,
#            '{ }',
#            'NYC Health and Hospitals - Coney Island (FKA Coney Island '
#            'Hospital)',
#            'Brooklyn',
#            'NY',
#            '$   66,231,249.80'],
#           ['row-x3kp_44dh~eb6e',
#            '00000000-0000-0000-3C08-51077ACD4E79',
#            0,
#            1588945919,
#            None,
#            1588945919,
#            None,
#            '{ }',
#            'Southside Hospital',
#            'Bay Shore',
#            'NY',
#            '$   60,843,431.27'],
#           ['row-2tkr_cxp7.qfki',
#            '00000000-0000-0000-7F2C-086AA47E4D78',
#            0,
#            1588945919,
#            None,
#            1588945919,
#            None,
#            '{ }',
#            'Mount Sinai Morningside (FKA Mount Sinai St Lukes)',
#            'New York',
#            'NY',
#            '$   63,732,309.51'],
#           ['row-9jp4.gqmm_wian',
#            '00000000-0000-0000-E88F-7CCE04718235',
#            0,
#            1588945919,
#            None,
#            1588945919,
#            None,
#            '{ }',
#            'Englewood Hospital and Medical Center (AKA Englewood Health)',
#            'Englewood',
#            'NJ',
#            '$   53,635,316.22'],
#           ['row-kniu.keze~d73v',
#            '00000000-0000-0000-F073-2C0CA6B06FA6',
#            0,
#            1588945919,
#            None,
#            1588945919,
#            None,
#            '{ }',
#            'Henry Ford Macomb Hospital - Clinton Township',
#            'Clinton Township',
#            'MI',
#            '$   51,660,258.89'],
#           ['row-jejh_m9fa-rxd7',
#            '00000000-0000-0000-3C1A-EF74D4608D66',
#            0,
#            1588945919,
#            None,
#            1588945919,
#            None,
#            '{ }',
#            'Montefiore Wakefield Campus',
#            'Bronx',
#            'NY',
#            '$   72,958,947.60'],
#           ['row-zeic_u3re~tb9r',
#            '00000000-0000-0000-8E14-E3458D64F442',
#            0,
#            1588945919,
#            None,
#            1588945919,
#            None,
#            '{ }',
#            'Mount Sinai Queens',
#            'Astoria',
#            'NY',
#            '$   68,397,631.56'],
#           ['row-9vr6-b3ra.7wbd',
#            '00000000-0000-0000-E308-63ACA4380932',
#            0,
#            1588945919,
#            None,
#            1588945919,
#            None,
#            '{ }',
#            'The Valley Hospital (AKA Valley Health System)',
#            'Ridgewood',
#            'NJ',
#            '$   49,899,060.09'],
#           ['row-xekv-hnup-8yrr',
#            '00000000-0000-0000-E985-EA0F9CA7D984',
#            0,
#            1588945919,
#            None,
#            1588945919,
#            None,
#            '{ }',
#            'Richmond University Medical Center',
#            'Staten Island',
#            'NY',
#            '$   51,718,227.43'],
#           ['row-8ffz-6vpj_zbgf',
#            '00000000-0000-0000-DD00-0D986ED52F19',
#            0,
#            1588945919,
#            None,
#            1588945919,
#            None,
#            '{ }',
#            'Overlook Medical Center',
#            'Summit',
#            'NJ',
#            '$   50,659,617.68'],
#           ['row-p2v4-kd6g~wekm',
#            '00000000-0000-0000-4900-54A366908905',
#            0,
#            1588945919,
#            None,
#            1588945919,
#            None,
#            '{ }',
#            'Good Samaritan Hospital Medical Center',
#            'West Islip',
#            'NY',
#            '$   52,864,812.67'],
#           ['row-nfqk-m57s~ydva',
#            '00000000-0000-0000-41D6-440E6A1D166B',
#            0,
#            1588945919,
#            None,
#            1588945919,
#            None,
#            '{ }',
#            'Yale New Haven Hospital',
#            'New Haven',
#            'CT',
#            '$   59,728,988.60'],
#           ['row-djgw_fphe_8akf',
#            '00000000-0000-0000-891B-8DF30CBCA6AE',
#            0,
#            1588945919,
#            None,
#            1588945919,
#            None,
#            '{ }',
#            'Ascension St John Hospital',
#            'Detroit',
#            'MI',
#            '$   53,812,463.90'],
#           ['row-928y~nup8.93ca',
#            '00000000-0000-0000-5C88-359E4B274858',
#            0,
#            1588945919,
#            None,
#            1588945919,
#            None,
#            '{ }',
#            'Mount Sinai Brooklyn (AKA Mount Sinai Beth Israel Brooklyn Medical '
#            'Center - Kings Highway Division Brooklyn)',
#            'Brooklyn',
#            'NY',
#            '$   54,809,929.60'],
#           ['row-ay2h_new2~7y56',
#            '00000000-0000-0000-D199-DED9688BB430',
#            0,
#            1588945919,
#            None,
#            1588945919,
#            None,
#            '{ }',
#            'Morristown Medical Center',
#            'Morristown',
#            'NJ',
#            '$   47,395,253.21'],
#           ['row-pq46_6umb~6b3y',
#            '00000000-0000-0000-3C0F-16C301414BD7',
#            0,
#            1588945919,
#            None,
#            1588945919,
#            None,
#            '{ }',
#            'Flushing Hospital Medical Center',
#            'Flushing',
#            'NY',
#            '$   48,482,884.52'],
#           ['row-7zsr-w37r~xwpb',
#            '00000000-0000-0000-7FCC-378E289DD5CF',
#            0,
#            1588945919,
#            None,
#            1588945919,
#            None,
#            '{ }',
#            'University Hospital of Brooklyn at SUNY Downstate Medical Center',
#            'Brooklyn',
#            'NY',
#            '$   47,024,441.77'],
#           ['row-3yn8-weak~yr5a',
#            '00000000-0000-0000-236D-C501089D373B',
#            0,
#            1588945919,
#            None,
#            1588945919,
#            None,
#            '{ }',
#            'Newark Beth Israel Medical Center',
#            'Newark',
#            'NJ',
#            '$   50,645,428.38'],
#           ['row-rsep-jrds-jmsq',
#            '00000000-0000-0000-9EDF-3951ED4A4DAD',
#            0,
#            1588945919,
#            None,
#            1588945919,
#            None,
#            '{ }',
#            'Huntington Hospital',
#            'Huntington',
#            'NY',
#            '$   44,597,579.21'],
#           ['row-6c38_mb2w_786d',
#            '00000000-0000-0000-99CE-D39DCA61FBA2',
#            0,
#            1588945919,
#            None,
#            1588945919,
#            None,
#            '{ }',
#            'John H Stroger Jr Hospital of Cook County',
#            'Chicago',
#            'IL',
#            '$   59,380,168.85'],
#           ['row-ikws.5y3p-6ttw',
#            '00000000-0000-0000-66E0-DD55B66BDFCE',
#            0,
#            1588945919,
#            None,
#            1588945919,
#            None,
#            '{ }',
#            'Montefiore Nyack Hospital (FKA Nyack Hospital)',
#            'Nyack',
#            'NY',
#            '$   44,828,287.46'],
#           ['row-3gwm.zvqg_9myz',
#            '00000000-0000-0000-D7E7-8E6C969F0439',
#            0,
#            1588945919,
#            None,
#            1588945919,
#            None,
#            '{ }',
#            'DMC Sinai-Grace Hospital',
#            'Detroit',
#            'MI',
#            '$   46,856,480.74'],
#           ['row-8hdh.q9bv-7iw7',
#            '00000000-0000-0000-ACA1-FA92D99001C9',
#            0,
#            1588945919,
#            None,
#            1588945919,
#            None,
#            '{ }',
#            'St Barnabas Hospital',
#            'Bronx',
#            'NY',
#            '$   46,953,442.90'],
#           ['row-hua2_4qi8_zf78',
#            '00000000-0000-0000-0FE4-C514F3AE25B2',
#            0,
#            1588945919,
#            None,
#            1588945919,
#            None,
#            '{ }',
#            'Temple University Hospital',
#            'Philadelphia',
#            'PA',
#            '$   50,086,752.94'],
#           ['row-4jzp.q5kb-un6p',
#            '00000000-0000-0000-4930-084DFBA7510B',
#            0,
#            1588945919,
#            None,
#            1588945919,
#            None,
#            '{ }',
#            'Massachusetts General Hospital',
#            'Boston',
#            'MA',
#            '$   52,294,070.60'],
#           ['row-tseg-9ydv-2zm3',
#            '00000000-0000-0000-E377-432DA793994A',
#            0,
#            1588945919,
#            None,
#            1588945919,
#            None,
#            '{ }',
#            'NewYork-Presbyterian Allen Hospital',
#            'New York',
#            'NY',
#            '$   76,926,186.32'],
#           ['row-2etw-f2e3~sqbe',
#            '00000000-0000-0000-765B-755D9C40FFB2',
#            0,
#            1588945919,
#            None,
#            1588945919,
#            None,
#            '{ }',
#            'St Francis Hospital - The Heart Center',
#            'Roslyn',
#            'NY',
#            '$   41,187,495.31'],
#           ['row-qp7d.4885-9e5r',
#            '00000000-0000-0000-674C-C8B60252BEFB',
#            0,
#            1588945919,
#            None,
#            1588945919,
#            None,
#            '{ }',
#            'Robert Wood Johnson University Hospital New Brunswick',
#            'New Brunswick',
#            'NJ',
#            '$   47,962,240.33'],
#           ['row-yc8k-mrq8.did2',
#            '00000000-0000-0000-C339-05C2F8A9453D',
#            0,
#            1588945919,
#            None,
#            1588945919,
#            None,
#            '{ }',
#            'Beaumont Hospital - Dearborn (FKA Oakwood Hospital - Dearborn)',
#            'Dearborn',
#            'MI',
#            '$   45,324,764.46'],
#           ['row-vran~pi4k~rz93',
#            '00000000-0000-0000-DD78-DBC0E44A8078',
#            0,
#            1588945919,
#            None,
#            1588945919,
#            None,
#            '{ }',
#            'Westchester Medical Center',
#            'Valhalla',
#            'NY',
#            '$   49,115,383.80'],
#           ['row-uht7.gpxq-5rpb',
#            '00000000-0000-0000-74EF-0D81351ACD1E',
#            0,
#            1588945919,
#            None,
#            1588945919,
#            None,
#            '{ }',
#            'St Johns Episcopal Hospital at South Shore',
#            'Far Rockaway',
#            'NY',
#            '$   42,083,162.48'],
#           ['row-74y9~hagp-6ziw',
#            '00000000-0000-0000-669A-154EF130D1DD',
#            0,
#            1588945919,
#            None,
#            1588945919,
#            None,
#            '{ }',
#            'Mount Sinai Beth Israel (FKA Mount Sinai Beth Israel Medical '
#            'Center Brooklyn Hospital Center)',
#            'New York',
#            'NY',
#            '$   46,958,400.47'],
#           ['row-yrz8.f4ig~cwqh',
#            '00000000-0000-0000-4549-81E830BBA0BE',
#            0,
#            1588945919,
#            None,
#            1588945919,
#            None,
#            '{ }',
#            'Advocate Christ Medical Center',
#            'Oak Lawn',
#            'IL',
#            '$   45,413,936.32'],
#           ['row-623y~5p2i-dkkm',
#            '00000000-0000-0000-54D9-5F25105F6464',
#            0,
#            1588945919,
#            None,
#            1588945919,
#            None,
#            '{ }',
#            'NYC Health and Hospitals - Harlem (FKA Harlem Hospital Center)',
#            'New York',
#            'NY',
#            '$   42,296,603.65'],
#           ['row-i5qs-k4ri-bprb',
#            '00000000-0000-0000-727A-7AFF2BD2CDA2',
#            0,
#            1588945919,
#            None,
#            1588945919,
#            None,
#            '{ }',
#            'Phoebe Putney Memorial Hospital',
#            'Albany',
#            'GA',
#            '$   41,606,782.43'],
#           ['row-wp6c_ecyp_etpa',
#            '00000000-0000-0000-7AC8-C9D14EEA2482',
#            0,
#            1588945919,
#            None,
#            1588945919,
#            None,
#            '{ }',
#            'CHA Cambridge Hospital',
#            'Cambridge',
#            'MA',
#            '$   40,721,351.41'],
#           ['row-jk25.m65s-n48e',
#            '00000000-0000-0000-2070-72D3E2E8E2B5',
#            0,
#            1588945919,
#            None,
#            1588945919,
#            None,
#            '{ }',
#            'Good Samaritan Hospital',
#            'Suffern',
#            'NY',
#            '$   39,262,377.99'],
#           ['row-quxx~tgzw-8h7y',
#            '00000000-0000-0000-A5A3-AEA284A36143',
#            0,
#            1588945919,
#            None,
#            1588945919,
#            None,
#            '{ }',
#            'Henry Ford West Bloomfield Hospital',
#            'West Bloomfield',
#            'MI',
#            '$   36,764,271.49'],
#           ['row-q3zn-qrxr_yuvb',
#            '00000000-0000-0000-B321-80EDD5F79A15',
#            0,
#            1588945919,
#            None,
#            1588945919,
#            None,
#            '{ }',
#            'Mount Sinai West (FKA Roosevelt Hospital Mount Sinai Roosevelt)',
#            'New York',
#            'NY',
#            '$   46,720,663.07'],
#           ['row-humn~6n3j.efh8',
#            '00000000-0000-0000-40D0-CE51C60AA7D4',
#            0,
#            1588945919,
#            None,
#            1588945919,
#            None,
#            '{ }',
#            'The University Hospital (FKA UMDNJ University Hospital)',
#            'Newark',
#            'NJ',
#            '$   42,010,050.78'],
#           ['row-v32g_i3w7-dbij',
#            '00000000-0000-0000-2B0C-D1BC40448DE4',
#            0,
#            1588945919,
#            None,
#            1588945919,
#            None,
#            '{ }',
#            'Jersey Shore University Medical Center',
#            'Neptune',
#            'NJ',
#            '$   39,649,464.90'],
#           ['row-gkaj~iepa~6j5n',
#            '00000000-0000-0000-A6EA-000A4AED3C6E',
#            0,
#            1588945919,
#            None,
#            1588945919,
#            None,
#            '{ }',
#            'Ascension Providence Hospital - Southfield Campus',
#            'Southfield',
#            'MI',
#            '$   38,238,726.82'],
#           ['row-b7gv.z6cm~i7bg',
#            '00000000-0000-0000-E127-5CA15A3B4406',
#            0,
#            1588945919,
#            None,
#            1588945919,
#            None,
#            '{ }',
#            'Von Voigtlander Womens Hospital',
#            'Ann Arbor',
#            'MI',
#            '$   45,512,678.84'],
#           ['row-3qxb_g4h7.4tm7',
#            '00000000-0000-0000-9E24-F24DB9421678',
#            0,
#            1588945919,
#            None,
#            1588945919,
#            None,
#            '{ }',
#            'Boston Medical Center',
#            'Boston',
#            'MA',
#            '$   49,209,124.68'],
#           ['row-sxyh.db9i~wkxd',
#            '00000000-0000-0000-6BFD-ED6276D88946',
#            0,
#            1588945919,
#            None,
#            1588945919,
#            None,
#            '{ }',
#            'Ascension Macomb-Oakland Hospital - Warren Campus',
#            'Warren',
#            'MI',
#            '$   37,448,911.71'],
#           ['row-krve_5kt5.gux2',
#            '00000000-0000-0000-D1BE-1A53296259F9',
#            0,
#            1588945919,
#            None,
#            1588945919,
#            None,
#            '{ }',
#            'NYC Health and Hospitals - Woodhull (FKA Woodhull Medical and '
#            'Mental Health Center)',
#            'Brooklyn',
#            'NY',
#            '$   39,900,635.33'],
#           ['row-fki8~djav~duwg',
#            '00000000-0000-0000-BFED-BC03A4EAA04B',
#            0,
#            1588945919,
#            None,
#            1588945919,
#            None,
#            '{ }',
#            'Tanner Medical Center - Carrollton',
#            'Carrollton',
#            'GA',
#            '$   35,224,580.04'],
#           ['row-tymp.6szn.kf6m',
#            '00000000-0000-0000-91E4-33E527435FE0',
#            0,
#            1588945919,
#            None,
#            1588945919,
#            None,
#            '{ }',
#            'Clara Maass Medical Center',
#            'Belleville',
#            'NJ',
#            '$   36,496,914.76'],
#           ['row-i4uj_rvc2.j56g',
#            '00000000-0000-0000-5923-24B643FC3CD3',
#            0,
#            1588945919,
#            None,
#            1588945919,
#            None,
#            '{ }',
#            'NewYork-Presbyterian Lawrence Hospital (FKA Lawrence Hospital '
#            'Center)',
#            'Bronxville',
#            'NY',
#            '$   33,253,535.11'],
#           ['row-uehm~546x.56se',
#            '00000000-0000-0000-79E9-0F0C8BEFACD7',
#            0,
#            1588945919,
#            None,
#            1588945919,
#            None,
#            '{ }',
#            'New York Community Hospital of Brooklyn',
#            'Brooklyn',
#            'NY',
#            '$   36,591,243.75'],
#           ['row-p29y-f936.hrez',
#            '00000000-0000-0000-38F9-D16673D5A547',
#            0,
#            1588945919,
#            None,
#            1588945919,
#            None,
#            '{ }',
#            'University Medical Center New Orleans (FKA Medical Center of '
#            'Louisiana at New Orleans and Interim LSU Public Hospital)',
#            'New Orleans',
#            'LA',
#            '$   50,768,425.38'],
#           ['row-hide-7kny~yqxw',
#            '00000000-0000-0000-6462-285382509124',
#            0,
#            1588945919,
#            None,
#            1588945919,
#            None,
#            '{ }',
#            'Franciscan Health Indianapolis (FKA Franciscan St Francis Health - '
#            'Indianapolis)',
#            'Indianapolis',
#            'IN',
#            '$   37,496,901.46'],
#           ['row-d2sf-jvw7~9i3c',
#            '00000000-0000-0000-EDB7-9F672AD8FB9C',
#            0,
#            1588945919,
#            None,
#            1588945919,
#            None,
#            '{ }',
#            'Hartford Hospital',
#            'Hartford',
#            'CT',
#            '$   37,899,728.27'],
#           ['row-ujmb-rryq~486r',
#            '00000000-0000-0000-429E-19A657813738',
#            0,
#            1588945919,
#            None,
#            1588945919,
#            None,
#            '{ }',
#            'Hackensack Meridian Health Mountainside Medical Center',
#            'Montclair',
#            'NJ',
#            '$   32,521,807.07'],
#           ['row-3vk4-an3k~5keh',
#            '00000000-0000-0000-BD0C-8EB58D7A658B',
#            0,
#            1588945919,
#            None,
#            1588945919,
#            None,
#            '{ }',
#            'Mercy Medical Center',
#            'Rockville Centre',
#            'NY',
#            '$   33,005,251.86'],
#           ['row-3uc7.mkcz-h3zw',
#            '00000000-0000-0000-26EC-D41DB20F663E',
#            0,
#            1588945919,
#            None,
#            1588945919,
#            None,
#            '{ }',
#            'Brooklyn Hospital Center at Downtown Campus',
#            'Brooklyn',
#            'NY',
#            '$   35,200,496.62'],
#           ['row-kxkf.jtwx~sqj6',
#            '00000000-0000-0000-4D8B-5BA375B5B790',
#            0,
#            1588945919,
#            None,
#            1588945919,
#            None,
#            '{ }',
#            'Baton Rouge General Medical Center - Mid City Campus',
#            'Baton Rouge',
#            'LA',
#            '$   34,066,409.96'],
#           ['row-a47e~uprs-y6z9',
#            '00000000-0000-0000-BBAB-47CC6B404F54',
#            0,
#            1588945919,
#            None,
#            1588945919,
#            None,
#            '{ }',
#            'Jersey City Medical Center',
#            'Jersey City',
#            'NJ',
#            '$   35,157,665.69'],
#           ['row-va58~hu5w.a8jy',
#            '00000000-0000-0000-8CC3-88995602C431',
#            0,
#            1588945919,
#            None,
#            1588945919,
#            None,
#            '{ }',
#            'Cooper University Hospital (AKA Cooper University Health Care)',
#            'Camden',
#            'NJ',
#            '$   39,164,374.99'],
#           ['row-9vrr-z34u~j86m',
#            '00000000-0000-0000-8EAA-58F36E140A43',
#            0,
#            1588945919,
#            None,
#            1588945919,
#            None,
#            '{ }',
#            'Beaumont Hospital - Farmington Hills (FKA Botsford Hospital)',
#            'Farmington Hills',
#            'MI',
#            '$   31,624,667.47'],
#           ['row-p3kr~723h-tczw',
#            '00000000-0000-0000-6A13-590CD7EA5634',
#            0,
#            1588945919,
#            None,
#            1588945919,
#            None,
#            '{ }',
#            'DMC Detroit Receiving Hospital',
#            'Detroit',
#            'MI',
#            '$   33,579,824.09'],
#           ['row-i2v5.u4up.rm6x',
#            '00000000-0000-0000-F7E1-E57CDF9B75C3',
#            0,
#            1588945919,
#            None,
#            1588945919,
#            None,
#            '{ }',
#            'Beaumont Hospital - Troy',
#            'Troy',
#            'MI',
#            '$   31,140,456.18'],
#           ['row-6p7d-ni2v~ytw3',
#            '00000000-0000-0000-E71D-7578CAB50105',
#            0,
#            1588945919,
#            None,
#            1588945919,
#            None,
#            '{ }',
#            'Kingsbrook Jewish Medical Center',
#            'Brooklyn',
#            'NY',
#            '$   30,844,020.89'],
#           ['row-67ft_p5kt_eu3h',
#            '00000000-0000-0000-BE73-BEBFCB98B1AC',
#            0,
#            1588945919,
#            None,
#            1588945919,
#            None,
#            '{ }',
#            'Christ Hospital',
#            'Jersey City',
#            'NJ',
#            '$   31,704,080.68'],
#           ['row-9xni.g56u-hpne',
#            '00000000-0000-0000-B5C6-B682D2D37DB0',
#            0,
#            1588945919,
#            None,
#            1588945919,
#            None,
#            '{ }',
#            'Palos Health (AKA Palos Community Hospital)',
#            'Palos Heights',
#            'IL',
#            '$   29,040,652.16'],
#           ['row-j9qp.s8sv~b36m',
#            '00000000-0000-0000-7A62-93901E57B066',
#            0,
#            1588945919,
#            None,
#            1588945919,
#            None,
#            '{ }',
#            'St Johns Riverside Hospital - Andrus Pavilion',
#            'Yonkers',
#            'NY',
#            '$   32,850,518.73'],
#           ['row-9ce7-f6rj-m25x',
#            '00000000-0000-0000-DFC4-E6D1A29350C2',
#            0,
#            1588945919,
#            None,
#            1588945919,
#            None,
#            '{ }',
#            'Palisades Medical Center',
#            'North Bergen',
#            'NJ',
#            '$   30,279,931.41'],
#           ['row-rirk.7uqj_qajd',
#            '00000000-0000-0000-3615-2C3DCF4D33E9',
#            0,
#            1588945919,
#            None,
#            1588945919,
#            None,
#            '{ }',
#            'Northwestern Memorial Hospital',
#            'Chicago',
#            'IL',
#            '$   34,692,432.89'],
#           ['row-5y2w.kbia~5uvf',
#            '00000000-0000-0000-0F28-CBD20DF8178F',
#            0,
#            1588945919,
#            None,
#            1588945919,
#            None,
#            '{ }',
#            'Ocean Medical Center',
#            'Brick',
#            'NJ',
#            '$   26,881,204.76'],
#           ['row-v4dr_m5vh-k7mx',
#            '00000000-0000-0000-F50C-158CFDD7DB5C',
#            0,
#            1588945919,
#            None,
#            1588945919,
#            None,
#            '{ }',
#            'UCHealth University of Colorado Hospital',
#            'Aurora',
#            'CO',
#            '$   36,588,557.77'],
#           ['row-hcpv-bznq_jq45',
#            '00000000-0000-0000-C35B-CD894F654BF3',
#            0,
#            1588945919,
#            None,
#            1588945919,
#            None,
#            '{ }',
#            'Beaumont Hospital - Grosse Pointe',
#            'Grosse Pointe',
#            'MI',
#            '$   28,142,201.21'],
#           ['row-9z5i_zubq_c49u',
#            '00000000-0000-0000-8B98-7BC26CC34C58',
#            0,
#            1588945919,
#            None,
#            1588945919,
#            None,
#            '{ }',
#            'Our Lady of the Lake Regional Medical Center',
#            'Baton Rouge',
#            'LA',
#            '$   35,251,861.16'],
#           ['row-gdff~bt2u.77a4',
#            '00000000-0000-0000-E10A-703A32BA7A9F',
#            0,
#            1588945919,
#            None,
#            1588945919,
#            None,
#            '{ }',
#            'Montefiore New Rochelle Hospital (FKA Sound Shore Medical Center '
#            'of Westchester)',
#            'New Rochelle',
#            'NY',
#            '$   27,970,630.71'],
#           ['row-tkz7.6m7z_dhfs',
#            '00000000-0000-0000-407B-09AD99C3AD38',
#            0,
#            1588945919,
#            None,
#            1588945919,
#            None,
#            '{ }',
#            'Saint Peters University Hospital',
#            'New Brunswick',
#            'NJ',
#            '$   29,574,037.75'],
#           ['row-6yqm.aq3x.9e9r',
#            '00000000-0000-0000-051B-E3A191753ADB',
#            0,
#            1588945919,
#            None,
#            1588945919,
#            None,
#            '{ }',
#            'Tanner Medical Center - Villa Rica',
#            'Villa Rica',
#            'GA',
#            '$   27,405,671.46'],
#           ['row-7zjm_m556-wx3z',
#            '00000000-0000-0000-2131-2A2F35FF1652',
#            0,
#            1588945919,
#            None,
#            1588945919,
#            None,
#            '{ }',
#            'St Mary Mercy Livonia Hospital',
#            'Livonia',
#            'MI',
#            '$   27,260,415.33'],
#           ['row-ndad~dm7r.ym3v',
#            '00000000-0000-0000-D41A-B4002296A51F',
#            0,
#            1588945919,
#            None,
#            1588945919,
#            None,
#            '{ }',
#            'Baystate Childrens Hospital',
#            'Springfield',
#            'MA',
#            '$   36,299,901.34'],
#           ['row-a8b5-pkig-pmhj',
#            '00000000-0000-0000-6280-A24D813732E3',
#            0,
#            1588945919,
#            None,
#            1588945919,
#            None,
#            '{ }',
#            'Baystate Medical Center',
#            'Springfield',
#            'MA',
#            '$   36,299,901.34'],
#           ['row-k4f8~t8pe-ynbu',
#            '00000000-0000-0000-6B21-BBCCB2929AC0',
#            0,
#            1588945919,
#            None,
#            1588945919,
#            None,
#            '{ }',
#            'West Jefferson Medical Center',
#            'Marrero',
#            'LA',
#            '$   28,367,163.41'],
#           ['row-pked-jjn4_cb5r',
#            '00000000-0000-0000-02B3-797EFB0460D4',
#            0,
#            1588945919,
#            None,
#            1588945919,
#            None,
#            '{ }',
#            'Franciscan Health Olympia Fields (FKA Franciscan St James Health - '
#            'Olympia Fields Campus)',
#            'Olympia Fields',
#            'IL',
#            '$   28,271,689.81'],
#           ['row-krny~8ima_zj3g',
#            '00000000-0000-0000-53E5-038085DDBC8B',
#            0,
#            1588945919,
#            None,
#            1588945919,
#            None,
#            '{ }',
#            'St Catherine of Siena Medical Center',
#            'Smithtown',
#            'NY',
#            '$   26,095,810.34'],
#           ['row-bvnv_2mek_a9rz',
#            '00000000-0000-0000-EC99-75EDC89E29F0',
#            0,
#            1588945919,
#            None,
#            1588945919,
#            None,
#            '{ }',
#            'Bridgeport Hospital',
#            'Bridgeport',
#            'CT',
#            '$   30,272,148.19'],
#           ['row-sn4r_uvk3.cw72',
#            '00000000-0000-0000-D288-F95149CF8D72',
#            0,
#            1588945919,
#            None,
#            1588945919,
#            None,
#            '{ }',
#            'NYC Health and Hospitals - Metropolitan (FKA Metropolitan Hospital '
#            'Center)',
#            'New York',
#            'NY',
#            '$   28,539,056.51'],
#           ['row-3f3r.g3wf~35fm',
#            '00000000-0000-0000-D9AD-62A4923735F5',
#            0,
#            1588945919,
#            None,
#            1588945919,
#            None,
#            '{ }',
#            'Plainview Hospital',
#            'Plainview',
#            'NY',
#            '$   25,741,447.71'],
#           ['row-z99n-yu5z_tbz3',
#            '00000000-0000-0000-4BB2-A272E0AF09E4',
#            0,
#            1588945919,
#            None,
#            1588945919,
#            None,
#            '{ }',
#            'Beth Israel Deaconess Medical Center',
#            'Boston',
#            'MA',
#            '$   32,513,523.87'],
#           ['row-2r66_cxi8_yapu',
#            '00000000-0000-0000-42EC-F9EDC46C98CB',
#            0,
#            1588945919,
#            None,
#            1588945919,
#            None,
#            '{ }',
#            'NYC Health and Hospitals - North Central Bronx (FKA North Central '
#            'Bronx Hospital)',
#            'Bronx',
#            'NY',
#            '$   27,517,018.67'],
#           ['row-d3tw~akcc~7qyz',
#            '00000000-0000-0000-008D-A7A2A0506DB7',
#            0,
#            1588945919,
#            None,
#            1588945919,
#            None,
#            '{ }',
#            'Rush University Medical Center',
#            'Chicago',
#            'IL',
#            '$   33,721,155.62'],
#           ['row-tcbg~3aku-2iwd',
#            '00000000-0000-0000-6817-2CDD60669BB4',
#            0,
#            1588945919,
#            None,
#            1588945919,
#            None,
#            '{ }',
#            'Community Medical Center',
#            'Toms River',
#            'NJ',
#            '$   26,451,303.91'],
#           ['row-5z7c~cxtw~2hsi',
#            '00000000-0000-0000-F978-1D8D4376E470',
#            0,
#            1588945919,
#            None,
#            1588945919,
#            None,
#            '{ }',
#            'Trinitas Regional Medical Center',
#            'Elizabeth',
#            'NJ',
#            '$   27,620,560.50'],
#           ['row-2649-7tbd~rm9f',
#            '00000000-0000-0000-BBB3-D6570F2E07C5',
#            0,
#            1588945919,
#            None,
#            1588945919,
#            None,
#            '{ }',
#            'Hoboken University Medical Center',
#            'Hoboken',
#            'NJ',
#            '$   25,498,510.66'],
#           ['row-j2w4_t3v9_6zrs',
#            '00000000-0000-0000-6D4B-9BE2BFF482B4',
#            0,
#            1588945919,
#            None,
#            1588945919,
#            None,
#            '{ }',
#            'Greenwich Hospital',
#            'Greenwich',
#            'CT',
#            '$   24,137,009.29'],
#           ['row-iqqt_q73a-rcdu',
#            '00000000-0000-0000-5852-746C8091E233',
#            0,
#            1588945919,
#            None,
#            1588945919,
#            None,
#            '{ }',
#            'Orange Regional Medical Center',
#            'Middletown',
#            'NY',
#            '$   27,638,223.64'],
#           ['row-z5pa_qeyg-s2ib',
#            '00000000-0000-0000-195D-9E3789017BF6',
#            0,
#            1588945919,
#            None,
#            1588945919,
#            None,
#            '{ }',
#            'RWJ University Hospital Somerset (FKA Somerset Medical Center)',
#            'Somerville',
#            'NJ',
#            '$   25,018,065.56'],
#           ['row-ndhm_xwn7.dwxa',
#            '00000000-0000-0000-1051-284D8123E1F8',
#            0,
#            1588945919,
#            None,
#            1588945919,
#            None,
#            '{ }',
#            'HSHS St Johns Hospital',
#            'Springfield',
#            'IL',
#            '$   27,940,970.21'],
#           ['row-96ey_2x2g_winv',
#            '00000000-0000-0000-3635-C1B18A324001',
#            0,
#            1588945919,
#            None,
#            1588945919,
#            None,
#            '{ }',
#            'UChicago Medicine Mitchell Hospital',
#            'Chicago',
#            'IL',
#            '$   36,065,914.97'],
#           ['row-qikh.redc.ymt3',
#            '00000000-0000-0000-32E3-EA27471DE0A5',
#            0,
#            1588945919,
#            None,
#            1588945919,
#            None,
#            '{ }',
#            'UChicago Medicine Center for Care and Discovery (AKA CCD)',
#            'Chicago',
#            'IL',
#            '$   36,065,914.97'],
#           ['row-648a-bqgc.ccxe',
#            '00000000-0000-0000-3F3E-1F7B70F536C6',
#            0,
#            1588945919,
#            None,
#            1588945919,
#            None,
#            '{ }',
#            'DMC Harper University Hospital',
#            'Detroit',
#            'MI',
#            '$   28,189,300.11'],
#           ['row-bzej-chx5_9k48',
#            '00000000-0000-0000-A774-36AE3CB6F678',
#            0,
#            1588945919,
#            None,
#            1588945919,
#            None,
#            '{ }',
#            'Stamford Hospital (AKA Stamford Health)',
#            'Stamford',
#            'CT',
#            '$   26,015,623.91'],
#           ['row-xkcb_yez3.4vi2',
#            '00000000-0000-0000-7F04-392690712F81',
#            0,
#            1588945919,
#            None,
#            1588945919,
#            None,
#            '{ }',
#            'Lehigh Valley Hospital - Cedar Crest',
#            'Allentown',
#            'PA',
#            '$   31,583,383.91'],
#           ['row-7uht-nij5-9ebu',
#            '00000000-0000-0000-0CA3-CF6F29BA956B',
#            0,
#            1588945919,
#            None,
#            1588945919,
#            None,
#            '{ }',
#            'Sisters of Charity Hospital',
#            'Buffalo',
#            'NY',
#            '$   24,003,213.31'],
#           ['row-hg67.ebku~m2wm',
#            '00000000-0000-0000-962A-9D620873A52F',
#            0,
#            1588945919,
#            None,
#            1588945919,
#            None,
#            '{ }',
#            'OU Medical Center',
#            'Oklahoma City',
#            'OK',
#            '$   35,818,349.04'],
#           ['row-7ah3-2kfi-sh8t',
#            '00000000-0000-0000-2013-00D957E24C23',
#            0,
#            1588945919,
#            None,
#            1588945919,
#            None,
#            '{ }',
#            'Evanston Hospital',
#            'Evanston',
#            'IL',
#            '$   27,120,623.49'],
#           ['row-j7v7_vpp2_93t2',
#            '00000000-0000-0000-227B-F37BC05E0BEE',
#            0,
#            1588945919,
#            None,
#            1588945919,
#            None,
#            '{ }',
#            'Danbury Hospital',
#            'Danbury',
#            'CT',
#            '$   24,565,396.51'],
#           ['row-ghi5~bbpn~6hzh',
#            '00000000-0000-0000-5B95-8E6BDAEDF5FE',
#            0,
#            1588945919,
#            None,
#            1588945919,
#            None,
#            '{ }',
#            'Raritan Bay Medical Center - Perth Amboy',
#            'Perth Amboy',
#            'NJ',
#            '$   24,758,340.37'],
#           ['row-gsin.ut3q.yiyd',
#            '00000000-0000-0000-F503-05C0B21AF0B6',
#            0,
#            1588945919,
#            None,
#            1588945919,
#            None,
#            '{ }',
#            'CentraState Medical Center',
#            'Freehold',
#            'NJ',
#            '$   21,939,749.48'],
#           ['row-ctuc_husg-z7f9',
#            '00000000-0000-0000-6B45-A147F0D8C0BD',
#            0,
#            1588945919,
#            None,
#            1588945919,
#            None,
#            '{ }',
#            'M Health Fairview St Josephs Hospital (FKA HealthEast St Josephs '
#            'Hospital)',
#            'Saint Paul',
#            'MN',
#            '$   24,265,858.37'],
#           ['row-smh5-ckea_93ze',
#            '00000000-0000-0000-DC1B-DA2349A313BA',
#            0,
#            1588945919,
#            None,
#            1588945919,
#            None,
#            '{ }',
#            'NewYork-Presbyterian Lower Manhattan Hospital (AKA New York '
#            'Downtown Hospital)',
#            'New York',
#            'NY',
#            '$   21,476,241.43'],
#           ['row-72dx_2dka~7dsp',
#            '00000000-0000-0000-A5E2-BFAC23FE6DA9',
#            0,
#            1588945919,
#            None,
#            1588945919,
#            None,
#            '{ }',
#            'St Lukes Cornwall Hospital - Newburgh Campus',
#            'Newburgh',
#            'NY',
#            '$   23,529,681.96'],
#           ['row-gnme-im5r~5ek8',
#            '00000000-0000-0000-7EA5-9FB76B50ECF7',
#            0,
#            1588945919,
#            None,
#            1588945919,
#            None,
#            '{ }',
#            'Thomas Jefferson University Hospital',
#            'Philadelphia',
#            'PA',
#            '$   29,937,796.39'],
#           ['row-wybf-4yr4-52j3',
#            '00000000-0000-0000-4316-4EFC3638D2C1',
#            0,
#            1588945919,
#            None,
#            1588945919,
#            None,
#            '{ }',
#            'Henry Ford Wyandotte Hospital',
#            'Wyandotte',
#            'MI',
#            '$   22,714,393.81'],
#           ['row-bgxx~6z25~ce35',
#            '00000000-0000-0000-2A14-03B5F5D920C6',
#            0,
# ...
#                                                             'item': 'Buffalo'},
#                                                            {'count': '2',
#                                                             'item': 'Baton '
#                                                                     'Rouge'}]},
#                                 'dataTypeName': 'text',
#                                 'description': '',
#                                 'fieldName': 'city',
#                                 'format': {},
#                                 'id': 466540666,
#                                 'name': 'City',
#                                 'position': 2,
#                                 'renderTypeName': 'text',
#                                 'tableColumnId': 101019191},
#                                {'cachedContents': {'cardinality': '33',
#                                                    'largest': 'WI',
#                                                    'non_null': '395',
#                                                    'null': '0',
#                                                    'smallest': 'AL',
#                                                    'top': [{'count': '90',
#                                                             'item': 'NY'},
#                                                            {'count': '53',
#                                                             'item': 'NJ'},
#                                                            {'count': '33',
#                                                             'item': 'IL'},
#                                                            {'count': '30',
#                                                             'item': 'MI'},
#                                                            {'count': '22',
#                                                             'item': 'MA'},
#                                                            {'count': '18',
#                                                             'item': 'GA'},
#                                                            {'count': '17',
#                                                             'item': 'PA'},
#                                                            {'count': '15',
#                                                             'item': 'LA'},
#                                                            {'count': '15',
#                                                             'item': 'FL'},
#                                                            {'count': '13',
#                                                             'item': 'CA'},
#                                                            {'count': '12',
#                                                             'item': 'IN'},
#                                                            {'count': '12',
#                                                             'item': 'CT'},
#                                                            {'count': '10',
#                                                             'item': 'MD'},
#                                                            {'count': '7',
#                                                             'item': 'WA'},
#                                                            {'count': '5',
#                                                             'item': 'AL'},
#                                                            {'count': '5',
#                                                             'item': 'CO'},
#                                                            {'count': '5',
#                                                             'item': 'MO'},
#                                                            {'count': '4',
#                                                             'item': 'OH'},
#                                                            {'count': '4',
#                                                             'item': 'NC'},
#                                                            {'count': '4',
#                                                             'item': 'VA'}]},
#                                 'dataTypeName': 'text',
#                                 'description': '',
#                                 'fieldName': 'state',
#                                 'format': {},
#                                 'id': 466540667,
#                                 'name': 'State',
#                                 'position': 3,
#                                 'renderTypeName': 'text',
#                                 'tableColumnId': 101019192},
#                                {'cachedContents': {'cardinality': '392',
#                                                    'largest': '$   '
#                                                               '9,966,384.92',
#                                                    'non_null': '395',
#                                                    'null': '0',
#                                                    'smallest': '$   '
#                                                                '10,052,815.10',
#                                                    'top': [{'count': '2',
#                                                             'item': '$   '
#                                                                     '36,299,901.34'},
#                                                            {'count': '2',
#                                                             'item': '$   '
#                                                                     '12,162,172.56'},
#                                                            {'count': '2',
#                                                             'item': '$   '
#                                                                     '36,065,914.97'},
#                                                            {'count': '1',
#                                                             'item': '$   '
#                                                                     '25,741,447.71'},
#                                                            {'count': '1',
#                                                             'item': '$   '
#                                                                     '16,013,590.08'},
#                                                            {'count': '1',
#                                                             'item': '$   '
#                                                                     '36,164,526.81'},
#                                                            {'count': '1',
#                                                             'item': '$   '
#                                                                     '17,366,062.75'},
#                                                            {'count': '1',
#                                                             'item': '$   '
#                                                                     '18,166,283.07'},
#                                                            {'count': '1',
#                                                             'item': '$   '
#                                                                     '20,006,365.53'},
#                                                            {'count': '1',
#                                                             'item': '$   '
#                                                                     '20,639,470.28'},
#                                                            {'count': '1',
#                                                             'item': '$   '
#                                                                     '27,940,970.21'},
#                                                            {'count': '1',
#                                                             'item': '$   '
#                                                                     '15,634,453.08'},
#                                                            {'count': '1',
#                                                             'item': '$   '
#                                                                     '11,320,844.62'},
#                                                            {'count': '1',
#                                                             'item': '$   '
#                                                                     '53,812,463.90'},
#                                                            {'count': '1',
#                                                             'item': '$   '
#                                                                     '203,180,446.74'},
#                                                            {'count': '1',
#                                                             'item': '$   '
#                                                                     '21,783,587.02'},
#                                                            {'count': '1',
#                                                             'item': '$   '
#                                                                     '17,781,781.31'},
#                                                            {'count': '1',
#                                                             'item': '$   '
#                                                                     '10,109,405.48'},
#                                                            {'count': '1',
#                                                             'item': '$   '
#                                                                     '20,651,187.85'},
#                                                            {'count': '1',
#                                                             'item': '$   '
#                                                                     '15,875,795.73'}]},
#                                 'dataTypeName': 'text',
#                                 'description': 'The amount allocated for the '
#                                                'provider in the COVID-19 '
#                                                'High-Impact Allocation.',
#                                 'fieldName': 'total_payments',
#                                 'format': {},
#                                 'id': 466540664,
#                                 'name': 'Total Payments',
#                                 'position': 4,
#                                 'renderTypeName': 'text',
#                                 'tableColumnId': 101019189}],
#                    'createdAt': 1588942400,
#                    'description': 'The bipartisan CARES Act and the Paycheck '
#                                   'Protection Program and Health Care '
#                                   'Enhancement Act provided $175 billion in '
#                                   'relief funds to hospitals and other '
#                                   'healthcare providers on the front lines of '
#                                   'the coronavirus response. The payments form '
#                                   'the $12 billion COVID-19 High-Impact '
#                                   'Allocation is being distributed by the '
#                                   'Department of Health and Human Services '
#                                   'through the Health Resources and Services '
#                                   'Administration to 395 hospitals who '
#                                   'provided inpatient care for 100 or more '
#                                   'COVID-19 patients through April 10, 2020. '
#                                   '$2 billion of these payments was '
#                                   'distributed to these hospitals based on '
#                                   'their Medicare disproportionate share and '
#                                   'uncompensated care payments. These 395 '
#                                   'hospitals accounted for 71 percent of '
#                                   'COVID-19 inpatient admissions reported to '
#                                   'HHS from nearly 6,000 hospitals around the '
#                                   'country.',
#                    'displayType': 'table',
#                    'downloadCount': 1920,
#                    'flags': ['default', 'restorable', 'restorePossibleForType'],
#                    'grants': [{'flags': ['public'],
#                                'inherited': False,
#                                'type': 'viewer'}],
#                    'hideFromCatalog': False,
#                    'hideFromDataJson': False,
#                    'id': 'b58h-s9zx',
#                    'license': {'name': 'Public Domain U.S. Government',
#                                'termsLink': 'https://www.usa.gov/government-works'},
#                    'licenseId': 'USGOV_WORKS',
#                    'metadata': {'availableDisplayTypes': ['table',
#                                                           'fatrow',
#                                                           'page'],
#                                 'custom_fields': {'Common Core': {'Bureau Code': '009:15',
#                                                                   'Contact Email': 'PRFdata@hrsa.gov',
#                                                                   'Contact Name': 'HRSA '
#                                                                                   'Chief '
#                                                                                   'Data '
#                                                                                   'Officer',
#                                                                   'Geographic Coverage': 'US',
#                                                                   'Program Code': '009:020',
#                                                                   'Publisher': 'HHS '
#                                                                                'ASPA',
#                                                                   'Update Frequency': 'Never'}},
#                                 'rowLabel': 'Each row is a provider who '
#                                             'received a payment from the $12 '
#                                             'billion COVID-19 High-Impact '
#                                             'Allocation from the Provider '
#                                             'Relief Fund, paid the week of May '
#                                             '4, 2020.'},
#                    'name': 'Provider Relief Fund COVID-19 High-Impact Payments',
#                    'newBackend': True,
#                    'numberOfComments': 0,
#                    'oid': 34095901,
#                    'owner': {'displayName': 'HHS ASPA',
#                              'flags': ['acceptedEula'],
#                              'id': 'tjyw-xtku',
#                              'screenName': 'HHS ASPA',
#                              'type': 'interactive',
#                              'userSegment': 'site_member'},
#                    'provenance': 'official',
#                    'publicationAppendEnabled': False,
#                    'publicationDate': 1588945920,
#                    'publicationGroup': 17102756,
#                    'publicationStage': 'published',
#                    'query': {},
#                    'rights': ['read'],
#                    'rowsUpdatedAt': 1588945919,
#                    'rowsUpdatedBy': 'tjyw-xtku',
#                    'tableAuthor': {'displayName': 'HHS ASPA',
#                                    'flags': ['acceptedEula'],
#                                    'id': 'tjyw-xtku',
#                                    'screenName': 'HHS ASPA',
#                                    'type': 'interactive',
#                                    'userSegment': 'site_member'},
#                    'tableId': 17102756,
#                    'tags': ['covid-19', 'provider relief fund'],
#                    'totalTimesRated': 0,
#                    'viewCount': 22914,
#                    'viewLastModified': 1588947321,
#                    'viewType': 'tabular'}}}

# %%
# Query to get the last value in the list, which is the fundings
# 8 = Place, 10 = State, -1 = Funds
data_json['data'][0][10]
# Out:
# 'NY'

# %%
# Getting the length of the request
len(data_json['data'])
# Out:
# 395

# %%
# # Creating lists to loop through the json request and append the data
locations = []
states = []
fundings = []

for x in range(len(data_json['data'])):
    locations.append(data_json['data'][x][8])
    states.append(data_json['data'][x][10])
    fundings.append(data_json['data'][x][-1])

# %%
# Transforming the 'fundings' list
# Remove the $ sign
fundings = [x.strip('$') for x in fundings]

# Remove the spaces in front
fundings = [x.strip(' ') for x in fundings]

# Remove the commas in between the numbers
new_fund = []
for x in fundings:
    y = x.replace(",","")
    new_fund.append(y)

# %%
# Change the data in the list to floats
new_fund = [float(x) for x in new_fund]
new_fund
# Out:
# [277653312.42,
#  213428946.86,
#  203180446.74,
#  143251512.11,
#  156708591.59,
#  137531542.64,
#  140754860.74,
#  152747325.41,
#  131500615.31,
#  111346403.33,
#  98138111.89,
#  91279199.85,
#  91357433.79,
#  118647056.76,
#  91535709.54,
#  108038387.94,
#  86952150.88,
#  88159157.24,
#  86705275.6,
#  75862417.9,
#  83300041.29,
#  75340417.34,
#  76138987.53,
#  78931188.49,
#  89200836.28,
#  75309433.06,
#  69678116.81,
#  65283067.19,
#  68677463.16,
#  66453550.17,
#  64596068.93,
#  71236299.82,
#  66309962.02,
#  66414763.53,
#  59603910.03,
#  59878470.75,
#  66231249.8,
#  60843431.27,
#  63732309.51,
#  53635316.22,
#  51660258.89,
#  72958947.6,
#  68397631.56,
#  49899060.09,
#  51718227.43,
#  50659617.68,
#  52864812.67,
#  59728988.6,
#  53812463.9,
#  54809929.6,
#  47395253.21,
#  48482884.52,
#  47024441.77,
#  50645428.38,
#  44597579.21,
#  59380168.85,
#  44828287.46,
#  46856480.74,
#  46953442.9,
#  50086752.94,
#  52294070.6,
#  76926186.32,
#  41187495.31,
#  47962240.33,
#  45324764.46,
#  49115383.8,
#  42083162.48,
#  46958400.47,
#  45413936.32,
#  42296603.65,
#  41606782.43,
#  40721351.41,
#  39262377.99,
#  36764271.49,
#  46720663.07,
#  42010050.78,
#  39649464.9,
#  38238726.82,
#  45512678.84,
#  49209124.68,
#  37448911.71,
#  39900635.33,
#  35224580.04,
#  36496914.76,
#  33253535.11,
#  36591243.75,
#  50768425.38,
#  37496901.46,
#  37899728.27,
#  32521807.07,
#  33005251.86,
#  35200496.62,
#  34066409.96,
#  35157665.69,
#  39164374.99,
#  31624667.47,
#  33579824.09,
#  31140456.18,
#  30844020.89,
#  31704080.68,
#  29040652.16,
#  32850518.73,
#  30279931.41,
#  34692432.89,
#  26881204.76,
#  36588557.77,
#  28142201.21,
#  35251861.16,
#  27970630.71,
#  29574037.75,
#  27405671.46,
#  27260415.33,
#  36299901.34,
#  36299901.34,
#  28367163.41,
#  28271689.81,
#  26095810.34,
#  30272148.19,
#  28539056.51,
#  25741447.71,
#  32513523.87,
#  27517018.67,
#  33721155.62,
#  26451303.91,
#  27620560.5,
#  25498510.66,
#  24137009.29,
#  27638223.64,
#  25018065.56,
#  27940970.21,
#  36065914.97,
#  36065914.97,
#  28189300.11,
#  26015623.91,
#  31583383.91,
#  24003213.31,
#  35818349.04,
#  27120623.49,
#  24565396.51,
#  24758340.37,
#  21939749.48,
#  24265858.37,
#  21476241.43,
#  23529681.96,
#  29937796.39,
#  22714393.81,
#  21227121.84,
#  21459942.36,
#  22422232.64,
#  36448160.63,
#  23203874.27,
#  26431710.62,
#  35215977.88,
#  21941396.85,
#  21783587.02,
#  19640036.07,
#  29260456.42,
#  22024680.29,
#  22817939.22,
#  21289694.72,
#  19502808.16,
#  27407566.16,
#  19447032.7,
#  25056339.01,
#  18320234.62,
#  18287982.75,
#  18166283.07,
#  20342406.84,
#  20312951.82,
#  19675274.96,
#  18305981.59,
#  19376850.71,
#  21227080.39,
#  24155685.46,
#  21125982.13,
#  19577250.65,
#  40466100.03,
#  21622010.72,
#  19116685.32,
#  29620679.41,
#  20006365.53,
#  26124369.3,
#  18946354.22,
#  16626767.56,
#  19737431.75,
#  18302571.52,
#  18267106.17,
#  33292073.58,
#  16318864.45,
#  16295632.02,
#  19115277.53,
#  16013590.08,
#  20628517.07,
#  17358109.41,
#  22807991.52,
#  16384996.65,
#  20098986.04,
#  24377600.32,
#  23164001.35,
#  16736504.68,
#  16783019.17,
#  19607167.5,
#  16231407.14,
#  17169264.55,
#  16510460.63,
#  17849050.78,
#  18877090.95,
#  15174844.39,
#  27228673.43,
#  18545187.71,
#  15634453.08,
#  18949206.58,
#  19599154.28,
#  15676285.36,
#  17469310.21,
#  15875795.73,
#  16411798.65,
#  25816209.29,
#  23522319.59,
#  21403754.11,
#  18487351.93,
#  16756018.94,
#  17775466.61,
#  14330782.18,
#  23557713.15,
#  16214029.27,
#  36164526.81,
#  17045370.51,
#  16678950.92,
#  13316809.2,
#  13990804.68,
#  20651187.85,
#  15607540.41,
#  15330983.97,
#  15109198.6,
#  16367055.58,
#  17993766.29,
#  49941627.17,
#  16629726.53,
#  14475453.07,
#  12430159.05,
#  12513351.05,
#  16256768.88,
#  14636188.59,
#  12351141.81,
#  20639470.28,
#  13651528.85,
#  12162172.56,
#  12162172.56,
#  14065906.87,
#  13084972.55,
#  16016126.8,
#  13647540.67,
#  12008221.01,
#  17781781.31,
#  14625058.6,
#  12139982.47,
#  11931245.24,
#  15853932.02,
#  16809538.96,
#  11885820.43,
#  13319380.54,
#  12800372.74,
#  16832242.76,
#  11529863.53,
#  34788831.18,
#  19806690.0,
#  11469390.58,
#  14942763.81,
#  27062560.75,
#  17225944.13,
#  17203431.51,
#  12368709.06,
#  24752277.71,
#  16563452.48,
#  12432647.59,
#  12308767.35,
#  18081456.23,
#  17691366.79,
#  13558165.21,
#  11644145.8,
#  10699632.83,
#  13242768.65,
#  15918050.42,
#  15732889.87,
#  13432421.71,
#  12154690.26,
#  21165464.28,
#  15355595.67,
#  13373417.54,
#  12390297.72,
#  15517528.54,
#  11731850.33,
#  10474523.28,
#  20139139.42,
#  15577814.92,
#  12936569.68,
#  10735899.93,
#  13245707.41,
#  12606762.36,
#  12271100.37,
#  12895992.55,
#  12910709.4,
#  11181812.38,
#  18130222.38,
#  10363767.38,
#  11937190.03,
#  10735622.73,
#  9867240.71,
#  14698036.92,
#  11320844.62,
#  9598319.61,
#  14545565.09,
#  12721821.43,
#  10625768.05,
#  10052815.1,
#  9544996.19,
#  14113939.62,
#  10227349.87,
#  45212166.72,
#  34353322.97,
#  16527427.41,
#  11040072.35,
#  9391044.64,
#  14727800.93,
#  10375247.58,
#  9314068.86,
#  12033664.73,
#  12662711.93,
#  10672102.22,
#  13032444.07,
#  12481964.86,
#  15465241.56,
#  14425888.51,
#  12930291.8,
#  9006165.76,
#  9166557.36,
#  24752283.5,
#  18760724.78,
#  15254592.19,
#  9463282.66,
#  10117947.51,
#  13340514.82,
#  11614624.41,
#  10194983.16,
#  10133012.43,
#  9868747.17,
#  15580690.05,
#  9121413.41,
#  9951773.38,
#  10243183.76,
#  18306017.53,
#  13183659.07,
#  10780487.24,
#  8881583.11,
#  8544311.11,
#  10402390.04,
#  10064068.7,
#  8558189.78,
#  12172442.55,
#  10109405.48,
#  8700862.06,
#  8313383.78,
#  12772119.93,
#  11525425.46,
#  10166311.5,
#  8550812.72,
#  22986059.66,
#  10320364.97,
#  10088955.48,
#  8654525.1,
#  8159432.23,
#  9940426.8,
#  8851468.33,
#  11092968.2,
#  10715660.45,
#  8711230.96,
#  9316630.98,
#  14810932.3,
#  12422113.9,
#  12041457.19,
#  11656685.99,
#  9966384.92,
#  8703109.13,
#  8025837.46,
#  19813761.4,
#  13212292.21,
#  10633280.26,
#  12759475.24,
#  11159933.8,
#  7774553.35,
#  17366062.75,
#  12783481.03,
#  10623281.57,
#  7697577.57]

# %%
# Creating a DataFrame to store the data
fund_dict = {
    "Location":locations,
    "State":states,
    "Funds":new_fund
}
fund_df = pd.DataFrame(fund_dict)
fund_df
# Out:
#                                               Location State         Funds
# 0                    Long Island Jewish Medical Center    NY  2.776533e+08
# 1      Holy Name Medical Center (AKA Holy Name Health)    NJ  2.134289e+08
# 2                                       Tisch Hospital    NY  2.031804e+08
# 3                          NewYork-Presbyterian Queens    NY  1.432515e+08
# 4                   Montefiore Hospital - Moses Campus    NY  1.567086e+08
# ..                                                 ...   ...           ...
# 390    University of Miami Health System (AKA UHealth)    FL  7.774553e+06
# 391                          HealthPark Medical Center    FL  1.736606e+07
# 392  Bethesda Hospital East (FKA Bethesda Memorial ...    FL  1.278348e+07
# 393                                 St Peters Hospital    NY  1.062328e+07
# 394                     Howard County General Hospital    MD  7.697578e+06
#
# [395 rows x 3 columns]

# %% [markdown]
# ## Loading DataFrames into database

# %%
# Create a connection to postgres
connection_string = "postgres:********@localhost:5432/ETL_Project"
engine = create_engine(f'postgresql://{connection_string}')

# %%
transformed_us_df.to_sql(name='nhe', con=engine, if_exists='append', index=True)

# %%
transformed_ebola_df.to_sql(name='ebola', con=engine, if_exists='append', index=True)

# %%
transformed_hiv_df.to_sql(name='hiv/aids', con=engine, if_exists='append', index=True)

# %%
covid_df.to_sql(name='covid_cases', con=engine, if_exists='append', index=True)

# %%
fund_df.to_sql(name='fundings', con=engine, if_exists='append', index=True)

# %%
# Confirm tables
engine.table_names()
# Out:
# ['nhe', 'ebola', 'hiv/aids', 'covid_cases', 'fundings']
